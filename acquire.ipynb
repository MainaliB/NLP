# %%
from requests import get
import pandas as pd
from bs4 import BeautifulSoup 
import os

# %%
# setting the url and the headers

url = 'https://codeup.com/codeups-data-science-career-accelerator-is-here/'

headers = {'User-Agent': 'Codeup Data Science'}

# %%
# sending request

response = get(url, headers=headers)

# %%
# getting the request in text format

response.text
# Out:
# '<!DOCTYPE html><html lang="en-US"><head >\t<meta charset="UTF-8" />\n\t<meta name="viewport" content="width=device-width, initial-scale=1" />\n\t\n\t<!-- This site is optimized with the Yoast SEO plugin v15.2 - https://yoast.com/wordpress/plugins/seo/ -->\n\t<title>Codeup’s Data Science Career Accelerator is Here! - Codeup</title>\n\t<meta name="description" content="The rumors are true! The time has arrived. Codeup has officially opened applications to our new Data Science career accelerator, with only 25 seats available! This immersive program is one of a kind in San Antonio, and will help you land a job in\xa0Glassdoor’s #1 Best Job in America." />\n\t<meta name="robots" content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" />\n\t<link rel="canonical" href="https://codeup.com/codeups-data-science-career-accelerator-is-here/" />\n\t<meta property="og:locale" content="en_US" />\n\t<meta property="og:type" content="article" />\n\t<meta property="og:title" content="Codeup’s Data Science Career Accelerator is Here! - Codeup" />\n\t<meta property="og:description" content="The rumors are true! The time has arrived. Codeup has officially opened applications to our new Data Science career accelerator, with only 25 seats available! This immersive program is one of a kind in San Antonio, and will help you land a job in\xa0Glassdoor’s #1 Best Job in America." />\n\t<meta property="og:url" content="https://codeup.com/codeups-data-science-career-accelerator-is-here/" />\n\t<meta property="og:site_name" content="Codeup" />\n\t<meta property="article:published_time" content="2018-09-30T05:26:22+00:00" />\n\t<meta property="article:modified_time" content="2020-10-14T20:17:22+00:00" />\n\t<meta property="og:image" content="https://codeup.com/wp-content/uploads/2018/10/Data-Science-7.png" />\n\t<meta property="og:image:width" content="1200" />\n\t<meta property="og:image:height" content="628" />\n\t<meta name="twitter:card" content="summary_large_image" />\n\t<meta name="twitter:label1" value="Written by">\n\t<meta name="twitter:data1" value="Dimitri Antoniou">\n\t<meta name="twitter:label2" value="Est. reading time">\n\t<meta name="twitter:data2" value="1 minute">\n\t<script type="application/ld+json" class="yoast-schema-graph">{"@context":"https://schema.org","@graph":[{"@type":"WebSite","@id":"https://codeup.com/#website","url":"https://codeup.com/","name":"Codeup","description":"Start your career in web development or data science. Accelerate yourself from beginner to job-ready professional in just 20 weeks. Get Hired or 100% money back*","potentialAction":[{"@type":"SearchAction","target":"https://codeup.com/?s={search_term_string}","query-input":"required name=search_term_string"}],"inLanguage":"en-US"},{"@type":"ImageObject","@id":"https://codeup.com/codeups-data-science-career-accelerator-is-here/#primaryimage","inLanguage":"en-US","url":"https://codeup.com/wp-content/uploads/2018/10/Data-Science-7.png","width":1200,"height":628},{"@type":"WebPage","@id":"https://codeup.com/codeups-data-science-career-accelerator-is-here/#webpage","url":"https://codeup.com/codeups-data-science-career-accelerator-is-here/","name":"Codeup\\u2019s Data Science Career Accelerator is Here! - Codeup","isPartOf":{"@id":"https://codeup.com/#website"},"primaryImageOfPage":{"@id":"https://codeup.com/codeups-data-science-career-accelerator-is-here/#primaryimage"},"datePublished":"2018-09-30T05:26:22+00:00","dateModified":"2020-10-14T20:17:22+00:00","author":{"@id":"https://codeup.com/#/schema/person/2da79c93ec98c5cc93026bee26751d2d"},"description":"The rumors are true! The time has arrived. Codeup has officially opened applications to our new Data Science career accelerator, with only 25 seats available! This immersive program is one of a kind in San Antonio, and will help you land a job in\\u00a0Glassdoor\\u2019s #1 Best Job in America.","inLanguage":"en-US","potentialAction":[{"@type":"ReadAction","target":["https://codeup.com ...

# %%
# creating a soup object using BeautifulSoup

soup = BeautifulSoup(response.content, 'html.parser')

# %%
# finding the division and the class of the portion of the information needed

article = soup.find('div', class_='jupiterx-post-content')
article.text
# Out:
# 'The rumors are true! The time has arrived. Codeup has officially opened applications to our new Data Science career accelerator, with only 25 seats available! This immersive program is one of a kind in San Antonio, and will help you land a job in\xa0Glassdoor’s #1 Best Job in America.\nData Science is a method of providing actionable intelligence from data.\xa0The data revolution has hit San Antonio,\xa0resulting in an explosion in Data Scientist positions\xa0across companies like USAA, Accenture, Booz Allen Hamilton, and HEB. We’ve even seen\xa0UTSA invest $70 M for a Cybersecurity Center and School of Data Science.\xa0We built a program to specifically meet the growing demands of this industry.\nOur program will be 18 weeks long, full-time, hands-on, and project-based. Our curriculum development and instruction is led by Senior Data Scientist, Maggie Giust, who has worked at HEB, Capital Group, and Rackspace, along with input from dozens of practitioners and hiring partners. Students will work with real data sets, realistic problems, and the entire data science pipeline from collection to deployment. They will receive professional development training in resume writing, interviewing, and continuing education to prepare for a smooth transition to the workforce.\nWe focus on applied data science for immediate impact and ROI in a business, which is how we can back it all up with a 6 month tuition refund guarantee – just like our existing Web Dev program. We’re focusing on Data Science with Python, SQL, and ML, covered in\xa014 modules: 1) Fundamentals; 2) Applied statistics; 3) SQL; 4) Python; 5) Supervised machine learning – regression; 6) Supervised machine learning – classification; 7) Unsupervised machine learning – clustering; 8) Time series analysis; 9) Anomaly detection; 10) Natural language processing; 11) Distributed machine learning; 12) Advanced topics (deep learning, NoSQL, cloud deployment, etc.); 13) Storytelling with data; and 14) Domain expertise development.\nApplications are now open\xa0for Codeup’s first Data Science cohort, which will start class on February 4, 2019. Hurry – there are only 25 seats available! To further our mission of cultivating inclusive growth, scholarships will be available to women, minorities, LGBTQIA+ individuals, veterans, first responders, and people relocating to San Antonio.\nIf you want to learn about joining our program or hiring our graduates, email datascience@codeup.com!\n\n'

# %%
# writing the text at the local repo
with open('article.txt', 'w') as f:
    f.write(article.text)

# %%
# creating the cache

def get_article_text():
    # if we already have the data, read it locally
    if path.exists('article.txt'):
        with open('article.txt') as f:
            return f.read()

    # otherwise go fetch the data
    url = 'https://codeup.com/codeups-data-science-career-accelerator-is-here/'
    headers = {'User-Agent': 'Codeup Data Science'}
    response = get(url, headers=headers)
    soup = BeautifulSoup(response.text)
    article = soup.find('div', class_='jupiterx-post-content')

    # save it for next time
    with open('article.txt', 'w') as f:
        f.write(article.text)

    return article.text

# %% [markdown]
# **Codeup Blog Articles**
#
# Scrape the article text from the following pages:

# %%
def get_blog_articles(url):
    '''Takes in a list of url, parses it using Beautiful Soup and returns a list of dictionaries
    of title as key and content as value'''
    lst = []
    for elem in url:
        headers = {'User-Agent': 'Codeup Data Science'}
        response = get(elem, headers = headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        title = soup.title.string
        article = soup.find('div', class_ = 'jupiterx-post-content')
        article_text = article.text
        item = {
            'title': title,
            'content': article_text
        }
        lst.append(item)
    return lst

# %%
elem = 'https://codeup.com/codeups-data-science-career-accelerator-is-here/'

headers = {'User-Agent': 'Codeup Data Science'}
response = get(elem, headers = headers)
soup = BeautifulSoup(response.content, 'html.parser')
title = soup.title.string
article = soup.find('div', class_ = 'jupiterx-post-content')
article.text
# Out:
# 'The rumors are true! The time has arrived. Codeup has officially opened applications to our new Data Science career accelerator, with only 25 seats available! This immersive program is one of a kind in San Antonio, and will help you land a job in\xa0Glassdoor’s #1 Best Job in America.\nData Science is a method of providing actionable intelligence from data.\xa0The data revolution has hit San Antonio,\xa0resulting in an explosion in Data Scientist positions\xa0across companies like USAA, Accenture, Booz Allen Hamilton, and HEB. We’ve even seen\xa0UTSA invest $70 M for a Cybersecurity Center and School of Data Science.\xa0We built a program to specifically meet the growing demands of this industry.\nOur program will be 18 weeks long, full-time, hands-on, and project-based. Our curriculum development and instruction is led by Senior Data Scientist, Maggie Giust, who has worked at HEB, Capital Group, and Rackspace, along with input from dozens of practitioners and hiring partners. Students will work with real data sets, realistic problems, and the entire data science pipeline from collection to deployment. They will receive professional development training in resume writing, interviewing, and continuing education to prepare for a smooth transition to the workforce.\nWe focus on applied data science for immediate impact and ROI in a business, which is how we can back it all up with a 6 month tuition refund guarantee – just like our existing Web Dev program. We’re focusing on Data Science with Python, SQL, and ML, covered in\xa014 modules: 1) Fundamentals; 2) Applied statistics; 3) SQL; 4) Python; 5) Supervised machine learning – regression; 6) Supervised machine learning – classification; 7) Unsupervised machine learning – clustering; 8) Time series analysis; 9) Anomaly detection; 10) Natural language processing; 11) Distributed machine learning; 12) Advanced topics (deep learning, NoSQL, cloud deployment, etc.); 13) Storytelling with data; and 14) Domain expertise development.\nApplications are now open\xa0for Codeup’s first Data Science cohort, which will start class on February 4, 2019. Hurry – there are only 25 seats available! To further our mission of cultivating inclusive growth, scholarships will be available to women, minorities, LGBTQIA+ individuals, veterans, first responders, and people relocating to San Antonio.\nIf you want to learn about joining our program or hiring our graduates, email datascience@codeup.com!\n\n'

# %%
url = ['https://codeup.com/codeups-data-science-career-accelerator-is-here/',
      'https://codeup.com/data-science-myths/',
      'https://codeup.com/data-science-vs-data-analytics-whats-the-difference/',
      'https://codeup.com/10-tips-to-crush-it-at-the-sa-tech-job-fair/',
       'https://codeup.com/competitor-bootcamps-are-closing-is-the-model-in-danger/',
       'https://codeup.com/introducing-salary-refund-guarantee/',
      'https://codeup.com/new-scholarship/']
my_list = get_blog_articles(url)

# %%
pd.DataFrame(my_list)
# Out:
#                                                title  \
# 0  Codeup’s Data Science Career Accelerator is He...
# 1                        Data Science Myths - Codeup
# 2  Data Science VS Data Analytics: What’s The Dif...
# 3  10 Tips to Crush It at the SA Tech Job Fair - ...
# 4  Competitor Bootcamps Are Closing. Is the Model...
# 5   Introducing Our Salary Refund Guarantee - Codeup
# 6  The Annie Easley Scholarship: Supporting Black...
#
#                                              content
# 0  The rumors are true! The time has arrived. Cod...
# 1  By Dimitri Antoniou and Maggie Giust\nData Sci...
# 2  By Dimitri Antoniou\nA week ago, Codeup launch...
# 3  SA Tech Job Fair\nThe third bi-annual San Anto...
# 4  Competitor Bootcamps Are Closing. Is the Model...
# 5  Here at Codeup, we believe it’s time to revolu...
# 6  We have an exciting announcement! We’re launch...

# %% [markdown]
# **News Articles**
#
# We will now be scraping text data from inshorts, a website that provides a brief overview of many different topics.
#
# Write a function that scrapes the news articles for the following topics:
#
# Business
#
# Sports
#
# Technology
#
# Entertainment
#
# The end product of this should be a function named get_news_articles that returns a list of dictionaries, where each dictionary has this shape:
#
# {
#     'title': 'The article title',
#     'content': 'The article content',
#     'category': 'business' # for example
# }

# %%
url= 'https://inshorts.com/en/news/scientist-behind-90-effective-covid19-vaccine-says-it-can-end-the-pandemic-1605240935577'
category = ['business', 'sports', 'technology', 'entertainment']
headers = {'User-Agent': 'Codeup Data Science'}
response = get(url, headers = headers)

soup = BeautifulSoup(response.content, 'html.parser')

title = soup.title.string

article = soup.find('div', itemprop = 'articleBody')

# item = {'title': title,
#         'content': article.text, 
#         'category': 
category = soup.find('li', class_ = 'active-category')

article
# Out:
# <div itemprop="articleBody">German scientist Uğur Şahin, the CEO of BioNTech which co-developed a coronavirus vaccine with Pfizer, said he's confident his product can end the pandemic and "bash the virus over the head." The vaccine is 90% effective based on initial data from a late-stage trial. "I believe that even protection only from symptomatic infections will have a dramatic effect," Şahin said.</div>

# %%
url1= 'https://inshorts.com/en/read/business'

url2 = 'https://inshorts.com/en/read/sports'
url3 = 'https://inshorts.com/en/read/technology'
url = 'https://inshorts.com/en/read/entertainment'
category = ['business', 'sports', 'technology', 'entertainment']
headers = {'User-Agent': 'Codeup Data Science'}
response = get(url, headers = headers)

soup = BeautifulSoup(response.content, 'html.parser')

# title = soup.title.string
# for elem in lst_url:
#     url = elem
#     headers = {'User-Agent': 'Codeup Data Science'}
#     response = get(url, headers = headers)
#     item = {'title': soup.title.string
#            'content':
#            'category': url.split('/')[-1] }

soup = BeautifulSoup(response.content, 'html.parser')


# item = {'title': ,
#         'content': article.text, 
#         'category': 


# soup.title.string
# url.split('/')[-1]
article = soup.find('span', itemprop = 'headline')
# Out:
# 'Entertainment News: Bollywood and Celebrity Gossip in English with Inshorts'

# %%
link = 'https://www.freep.com/story/news/politics/elections/2020/11/15/donald-trump-losing-michigan-lawsuits/6269524002/'
headers = {'user-agent': 'subscriber1'}

response = get(link)

response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, 'html.parser')

soup
# Out:
# <!DOCTYPE html>
# <html class="gnt__njs" lang="en-US"><head><meta charset="utf-8"/><meta content="width=device-width,initial-scale=1,minimum-scale=1" name="viewport"/><meta content="#0098FE" name="theme-color"/><title>Pro-Trump forces remain hitless in Michigan election challenges</title><meta content="Pro-Trump forces spin legal wheels in challenging Michigan election results" property="og:title"/><link href="https://amp.freep.com/amp/6269524002" rel="amphtml"/><meta content="Paul Egan and Clara Hendrickson" property="article:author"/><meta content="free" property="article:content_tier"/><meta content="false" property="article:opinion"/><link href="//user.freep.com" rel="dns-prefetch"/><link href="https://user.freep.com" rel="preconnect"/><link href="//content-static.gannett.com" rel="dns-prefetch"/><link href="//www.gannett-cdn.com" rel="dns-prefetch"/><link href="//securepubads.g.doubleclick.net" rel="dns-prefetch"/><link href="https://securepubads.g.doubleclick.net" rel="preconnect"/><link href="//adservice.google.com" rel="dns-prefetch"/><link href="https://adservice.google.com" rel="preconnect"/><link href="//tpc.googlesyndication.com" rel="dns-prefetch"/><link href="https://tpc.googlesyndication.com" rel="preconnect"/><link href="//googleads.g.doubleclick.net" rel="dns-prefetch"/><link href="//s0.2mdn.net" rel="dns-prefetch"/><link href="//partner.googleadservices.com" rel="dns-prefetch"/><link href="//www.googletagservices.com" rel="dns-prefetch"/><link href="https://www.googletagservices.com" rel="preconnect"/><link href="//static.adsafeprotected.com" rel="dns-prefetch"/><link href="https://static.adsafeprotected.com" rel="preconnect"/><link href="//pixel.adsafeprotected.com" rel="dns-prefetch"/><link crossorigin="" href="https://pixel.adsafeprotected.com" rel="preconnect"/><link href="//c.amazon-adsystem.com" rel="dns-prefetch"/><link href="//c.amazon-adsystem.com" rel="preconnect"/><link href="//js-sec.indexww.com" rel="dns-prefetch"/><link href="https://js-sec.indexww.com" rel="preconnect"/><link href="//aax.amazon-adsystem.com" rel="dns-prefetch"/><link href="//aax.amazon-adsystem.com" rel="preconnect"/><link href="//fastlane.rubiconproject.com" rel="dns-prefetch"/><link href="https://fastlane.rubiconproject.com" rel="preconnect"/><link href="//bidder.criteo.com" rel="dns-prefetch"/><link href="https://bidder.criteo.com" rel="preconnect"/><link href="//colossusssp.com" rel="dns-prefetch"/><link href="https://colossusssp.com" rel="preconnect"/><link href="//gannett-d.openx.net" rel="dns-prefetch"/><link href="https://gannett-d.openx.net" rel="preconnect"/><link href="//hbopenbid.pubmatic.com" rel="dns-prefetch"/><link href="https://hbopenbid.pubmatic.com" rel="preconnect"/><link href="//ads.pubmatic.com" rel="dns-prefetch"/><link href="//as-sec.casalemedia.com" rel="dns-prefetch"/><link href="https://as-sec.casalemedia.com" rel="preconnect"/><link href="//ib.adnxs.com" rel="dns-prefetch"/><link href="https://ib.adnxs.com" rel="preconnect"/><link href="//adserver.adtechus.com" rel="dns-prefetch"/><link href="https://adserver.adtechus.com" rel="preconnect"/><link href="//apex.go.sonobi.com" rel="dns-prefetch"/><link href="https://apex.go.sonobi.com" rel="preconnect"/><link href="//sofia.trustx.org" rel="dns-prefetch"/><link href="https://sofia.trustx.org" rel="preconnect"/><link href="//tlx.3lift.com" rel="dns-prefetch"/><link href="https://tlx.3lift.com" rel="preconnect"/><link href="//e.serverbid.com" rel="dns-prefetch"/><link href="https://e.serverbid.com" rel="preconnect"/><link href="//confiant-integrations.global.ssl.fastly.net" rel="dns-prefetch"/><link href="https://confiant-integrations.global.ssl.fastly.net" rel="preconnect"/><link href="https://s0.2mdn.net" rel="preconnect"/><link href="https://ads.adaptv.advertising.com" rel="preconnect"/><link href="https://search.spotxchange.com" rel="preconnect"/><link href="https://static.adsafeprotected.com" rel="preconnect"/><link href="https://imasdk.googleapis.com" rel="preconnect" ...
# if(c){const a=new c("Unify Sans",d,{display:"optional",weight:"700"});a.load();b.fonts.add(a)}else{const a=b.createElement("style");a.innerHTML='@font-face{font-family:"Unify Sans";src:'+d+";font-display:optional;font-weight:700}";b.head.appendChild(a)}};
# {const c=window,b=document,g=navigator,d=g.userAgent,a={};c.gnt={u:{},v:{},a7s:{dq:[],tq:[]},now:Date.now(),bn:{}};(a.t=(a.ip=a.i=1<g.maxTouchPoints&&d.includes("c OS X")&&
# !d.includes("(iP"))||(a.tn=(a.a=d.includes("; And"))||(a.in=a.i=d.includes("(iP"))))||(a.f=d.includes("Firefox"))||(a.e=d.includes("Edge"));;c.g$={run:[],d:b,de:b.documentElement,ec:encodeURIComponent,jp:JSON.parse,js:JSON.stringify,aeld:EventTarget.prototype.addEventListener,cached:{windowInnerHeight:innerHeight,windowInnerWidth:innerWidth},b:a,nv:g,ua:d,vv:c.visualViewport,el:{debounce:function(r){let l=-250,h;return function(a){if(!h){const b=a.timeStamp-l;250<b?(l=a.timeStamp,
# r(a)):h=setTimeout(()=>{h=0;l+=250;r(a)},250-b)}}}},intersectionObserverSupported:"IntersectionObserverEntry"in c&&"isIntersecting"in IntersectionObserverEntry.prototype}}try{if(g$.ls=window.localStorage)g$.ss=sessionStorage,g$.b.f&&g$.ls.getItem("gnt.test"),gnt.storage=!0}catch(c){}
# (function(){function c(b,c){let d={};if(b&&"string"===typeof b){c||(c="&");let g=b.charCodeAt(0);var a=0;let l;if("&"===c){if(63===g||35===g)a=1;for(;b.charAt(a)===c;)++a}for(;;){for(;" "===b.charAt(a);)++a;g=b.indexOf("=",a);let h=b.indexOf(c,a);if(0<g&&(g<h||-1===h))if(a=b.substring(a,g),0<h)for(d[a]=b.substring(g+1,a=h);b.charAt(++a)===c;);else{d[a]=b.substr(g+1);break}else if(0<h&&(h<g||-1===g))for(d[b.substring(a,h)]=!0,a=h+1;(l=b.charAt(a))===c||" "===l;)++a;else{a<b.length&&(d[b.substr(a)]=
# !0);break}}}return d}g$.parseQS=c;g$.hp=g$.hashParams=c(location.hash);g$.qsp=g$.qsParams=c(location.search);g$.ic=g$.initCookies=c(document.cookie,";")})();;
# if(g$.b.t&&!g$.hp["gnt-disable-vu"]){let c;const b=g$.vv,g=function(d){(c||(c=document.querySelector("meta[name=viewport]"))).content="width="+d};if(b&&g$.b.a){let c="device-width";b.addEventListener("resize",function(){var a=Math.round(b.width*b.scale);a=1024>=a?1024:1200<=a?1200:"device-width";c!==a&&g(c=a)})}else(1024>screen.width||1024>screen.height)&&g(1024)};;
# gnt.luxEnabled=performance.mark&&(.02>Math.random()||g$.hp["gnt-enable-lux"])&&!g$.hp["gnt-disable-lux"];(g$.ut=performance.mark&&(gnt.luxEnabled||g$.hp["gnt-perf"])?c=>{performance.mark(c)}:()=>{})("gnt head");;
# {const c=g$,{hp:b,ic:g,d,de:a}=c,{"gnt-user-cookiesMissing":r,"gnt-user-status":l,"gnt-user-ccpaout":h}=b,m=g.gup_lng,p=gnt,f=p.u;let e;if(m)try{e=f.lng=JSON.parse(decodeURIComponent(m))}catch(G){}e||(e=f.lng={auth:!1,hma:!1,lic:"none",name:"","ret-sub":!1,"ret-user":!1,nfc:!0});const q=a.classList,w=l&&"string"===typeof l,x="sub"===l,z=x||"reg"===l,D=!(f.cm="boolean"===typeof r?r:!g.gup_lsid&&!z),n=f.au=w?z:D&&e.auth,E=f.hma=w?x:n&&e.hma,u=f.lt=b["gnt-user-licensetype"]||e.lic,C=f.wn=b["gnt-user-welcomename"]||
# e.name;f.rs=b["gnt-user-retsub"]||e["ret-sub"];f.ru=e["ret-user"];;n&&u&&u.endsWith("plus")&&(f.adfree=!0,q.add("gnt__hx"));;
# n&&C&&(a.style.setProperty("--gnt-uwn","'"+C+"'"),a.setAttribute("data-u-n",""));a.setAttribute("data-u-s",f.s=n?E?"sub":"reg":"anon");;if(!b["gnt-disable-ccpa"]){let a,b,c=";path=/;secure;samesite=lax;priority=high;max-age=31536000",
# e=g.OptanonConsent,k=g.usprivacy;if(p.storage){const a=localStorage,b=a.getItem("gnt.u.oc");if(!e&&b)d.cookie="OptanonConsent="+(e=b)+";domain=freep.com"+c;else if(e&&e!==b)try{a.setItem("gnt.u.oc",e)}catch(B){}}const l=Object.defineProperty,m=e&&e.length&&(-1<e.indexOf("on=US%3BCA")||-1<e.indexOf("on=US%3BNV"))?-1<(a=e.indexOf("groups="))&&(-1<(a="%2C"+e.substr(a+7)).indexOf("%2C4%3A0")||-1<a.indexOf("%2C5%3A0"))?2:1:0,n=f.co=h||2===m||k&&k[2]&&"Y"===k[2].toUpperCase(),r=function(v,
# A,B){if("getUSPData"===v&&"function"===typeof B)try{B({uspString:b,version:1},!0)}catch(H){}},q=function(){d.cookie="usprivacy="+b+c};k!==(b=m||k&&"1---"!==k?n?"1YYY":"1YNY":"1---")&&q();try{l(p,"usp",{enumerable:!0,get:function(){return b},set:function(v){b===v||h||(f.co="1YYY"===(b=v),q())}}),l(window,"__uspapi",{enumerable:!0,value:r})}catch(v){}}};
#   (g$.nv.share||g$.hp["gnt-enable-shareapi"])&&document.documentElement.setAttribute("data-ss-sa","");
#
#
#   g$.de.classList.remove("gnt__njs");
#
# ;;
# gnt.v.sp=!0;try{Object.defineProperty(window,"_sp_",{value:{config:{account_id:308}}})}catch(c){};</script><style>@font-face{font-family:'Unify Sans';src:local('☺︎')}@media not all and (min-resolution:.001dpcm){@media{@font-face{font-family:'Unify Sans';src:local('Helvetica Neue')}}}html{margin:0;padding:0;background:#fff;overflow-y:scroll;-webkit-text-size-adjust:none;text-size-adjust:none}body{overflow:visible!important;margin:0;padding:0;background:unset;font:10px/13px 'Helvetica Neue','Arial Nova',Helvetica,Arial,sans-serif}img:not([src]):not([srcset]){visibility:hidden}img:-moz-loading{visibility:hidden}:focus{outline-color:#0098fe}.gnt_cw{display:flex;flex-wrap:wrap;align-items:stretch;width:980px;margin:20px auto 0;padding:0 10px;flex-shrink:0;position:relative;background:#fff}.gnt_pr{width:660px;margin-right:auto}.gnt_rr{contain:layout;overflow-anchor:none;width:300px}@media (min-width:1200px){.gnt_cw{align-content:start;width:1020px;min-height:480px;margin:30px auto 0;padding:0 60px}}.gnt_ar_hl{margin:6px 0 0;color:#303030;font:700 36px/38px 'Unify Sans','Helvetica Neue','Arial Nova',Helvetica,Arial,sans-serif}.gnt_bc{min-width:1000px;height:20px;margin:0 0 -20px;background:#0098fe}@media (min-width:1200px){.gnt_bc{height:480px;margin:0 0 -480px}}.gnt_cw_w{isolation:isolate;display:flex;justify-content:space-between;min-width:1000px}.gnt_cw_sl{overflow-anchor:none;width:calc(50% - 500px);outline:0}.gnt_cw_sl__ed{order:3}.gnt_xbr{display:none}@media (min-width:1200px){.gnt_cw_sl{width:calc(50% - 570px)}.gnt_xbr{overflow-anchor:none;display:block;width:0}.gnt_ar_xb{display:inline-block;position:-webkit-sticky;position:sticky;top:187px;transform:translate(36px,-58px);width:36px;height:36px;margin:0 0 -17px;border:4px solid #fff;border-radius:50%;background:#303030}.gnt__hx .gnt_ar_xb{transform:translate(36px,-72px)}.gnt_ar_xb::before{content:'';position:absolute;top:17px;left:10px;transform:rotate(45deg);width:16px;height:2px;background:#fff}.gnt_ar_xb::after{content:'';position:absolute;top:17px;left:10px;transform:rotate(-45deg);width:16px;height:2px;background:#fff}.gnt_ar_xb:hover{background:#000}}html:not(.gnt__njs) .gnt__hbd{display:none;background:unset}.gnt_ft{width:880px;height:750px;margin:-10px auto 0;padding:0 10px;color:#303030;-webkit-user-select:none;user-select:none}.gnt_ft_lg{display:block;width:281.88px;height:40px;margin:46px 0 48px;padding:0 0 16px 0;background:url(/tangstatic/svg/leghorn/usatnetwork-q1a2z3aa2e396b.svg) 0 bottom/178px 8px no-repeat}.gnt_ft_lw{display:flex;justify-content:space-between;margin:0 0 -541px}.gnt_ft_ls{display:flex;flex-flow:column;width:196px}.gnt_ft_ls::before{content:attr(aria-label);margin:0 0 -1px;font:700 14px/16px 'Helvetica Neue','Arial Nova',Helvetica,Arial,sans-serif}.gnt_ft_a{margin:16px auto 0 -2px;padding:0 2px;border:0;background:0 0;color:#303030;font:14px/18px 'Georgia Pro',Georgia,'Droid Serif',serif;text-decoration:none;text-align:left;cursor:pointer}.gnt_ft_a:hover{color:#000}.gnt_ft_a__bl{font-weight:700}.gnt_ft_cr{padding:570px 0 58px;font:12px/14px 'Georgia Pro',Georgia,'Droid Serif',serif}@media (min-width:1200px){.gnt_ft{padding:0 60px}}.gnt_x{margin:46px auto}.gnt_x_sl{contain:content;transform:translate3d(0,0,0);width:300px;min-height:250px;background-color:#f8f8f8;margin:auto;position:relative}.gnt_x__lbl::before{content:var(--gnt-x-lbl, 'Advertisement');text-align:center;color:#787878;font:10px/18px 'Helvetica Neue','Arial Nova',Helvetica,Arial,sans-serif;display:block}.gnt_x__lh::before{opacity:0}.gnt_x_sl_gpt:empty{display:none!important}.gnt_x__st{position:-webkit-sticky;position:sticky;top:140px;margin-top:32px}.gnt_x_sl__st{transform:unset;will-change:unset}.gnt_x_lb{contain:strict;overflow:hidden;transform:translate3d(0,0,0);width:728px;height:90px;background-color:#f8f8f8;margin:auto}.gnt__hx .gnt_tb,.gnt__hx .gnt_x{display:none}.gnt_x__hi{contain:layout;margin:6px auto 18px;padding:0;--gnt-x-lbl:'Advertisement - scroll for more content'}. ...
#     g$.ut("gnt bodyend");gnt.addScript=(a,e,c,h,k,b)=>{const g=document.createElement("script");g.src=a;e&&(g.async=e);k&&(g.crossOrigin=k);c&&(g.onload=c);h&&(g.onerror=h);b&&b(g);document.head.appendChild(g)};;
# gnt.data={a7sPre:"story pages|news",adAamProps:"tangent-desktop|desktop|story pages",adBuild:"tangent-full,tangent-desktop",
# adPageType:"story",adTopic:"michigan-elections,donald-trump,elections,joe-biden,michigan-secretary-of-states-office,us-federal-court,michigan-court-of-appeals,wayne-county,-mi",contentDatePublished:"2020-11-15T11:02:25Z",baseName:"freep",canonicalURL:"https://www.freep.com/story/news/politics/elections/2020/11/15/donald-trump-losing-michigan-lawsuits/6269524002/",
# clientActionSource:"story",contentByline:"paul egan,clara hendrickson",contentContributorNames:"paul egan,clara hendrickson",contentCstCategory:"news",contentCstSubcategory:"news:politics",contentCstTopic:"news:politics",
# cstCategory:"news",cstSubcategory:"politics",contentHeadline:"Pro-Trump forces spin legal wheels in challenging Michigan election results",
# contentId:"6269524002",contentKeywords:"michigan elections,donald trump,elections,joe biden,michigan secretary of state's office,u.s. federal court,michigan court of appeals,wayne county, mi",contentName:"/story/news/politics/elections/2020/11/15/donald-trump-losing-michigan-lawsuits/6269524002/",contentProtectionState:"free",contentSource:"Detroit Free Press",
# contentSstsSection:"news",contentSstsSubsection:"news:politics",contentSstsSubtopic:"news:politics:elections",contentSstsTopic:"news:politics:elections",sectionName:"news",subSectionName:"politics",
# topicName:"elections",contentType:"story pages",eventGroupName:"cet",fbappid:"185931034751252",twitterAccount:"freep",taboolaPageType:"article",
# taboolaPublisherId:"gannett-network",pageExperienceType:"desktop",
# pageExperienceVersion:"tangent",pageHasVideo:"yes",pageHasVideoAutoplay:"true",publicationDomain:"freep.com",shareLocation:"top,bottom",siteCode:"PDTF",siteId:"425",sstsPath:"news/politics/elections",storyHighlights:"no story highlights",
# v:"0.2366.0"};;(function(){function a(){l=new Promise((a,b)=>{A=a;w=b});l.catch(()=>{})}const e=gnt,{a7s:{tq:c},storage:h,u:k}=e,b=g$,{ls:g,jp:n,js:B}=b,m=k.localUserJson=h&&g.getItem("gupUserInfo"),q=h&&g.getItem("user_insights");let p,t,l,A,w,f,d,u;if(m)try{(k.localUser=k.user=n(m)).local=!0}catch(C){}if(q)try{u=n(q)}catch(C){}u||(u={});u.local=!0;k.insights=u;k.getUser=function(){if(!d&&(f||(f=setTimeout(()=>{f=0;A({timedOut:!0});a()},3E3)),!p||t)){a();t=!1;const c=gnt.data;p=fetch("https://user."+
# c.publicationDomain+"/"+c.siteCode+"-GUP/user/",{credentials:"include",cache:"no-store"}).then(a=>{a.json().then(a=>{b.ut("gnt userDataLoaded");if(a){const b=a.response&&a.response.insights;if(b&&(k.insights=u=b,h))try{const a=B(b);a!==q&&g.setItem("user_insights",a)}catch(z){}if(h)try{const b=B(a);m!==b&&g.setItem("gupUserInfo",b)}catch(z){}}A(k.user=d=a);clearTimeout(f);p=f=0}).catch(a=>{t=!0;clearTimeout(f);p=f=0;w(a)})}).catch(a=>{t=!0;clearTimeout(f);p=f=0;w(a)})}return l};})();;
# if(!g$.hp["gnt-disable-ot"]){let a,e,c,h,k,b,g,n,B,m;const q="https://geolocation.",p="/cookieconsentpub/v1/geo/location/gnt.otgc",t=gnt,l=g$,A=t.addScript,w=l.d,f=window;g$.run.push(()=>{g=l.mods.base.handlers.click.ottid=function(){a=!0;!e&&c?(k=!0,t.otgc(c)):f.OneTrust&&OneTrust.ToggleInfoDisplay&&(n&&(l.de.dispatchEvent(n),n=0),m&&!m.isConnected&&w.head.appendChild(m),B&&OneTrust.ToggleInfoDisplay())};t.otfu=function(a){if(h){if(t.otfu=()=>{},a=w.querySelector('[data-g-r="base_ottid"]'))a.textContent=
# "Cookie Settings"}else a&&(b=1)}});t.otgc=function(d){c=d;const u=l.hp["gnt-test-otgs"],C=!d||"error"===d.type,H=(d||(d={})).state=(u||d.state||"").toUpperCase(),F="CA"===H||"NV"===H;e=F||C||k||l.hp["gnt-enable-ot"];l.ut("gnt otg"+(C?"f":"l"));F||C&&!u||k||(h=!0,b&&t.otfu());if(e){var I="https://cdn.cookielaw.org/";const b="01e4d74e-5d5c-462e-a4ac-2a6118b4b440",c=I+"scripttemplates/otSDKStub.js";I=I+"consent/"+b+"/";const e=l.preload;if(!C||u)F&&"1---"===t.usp&&(t.usp="1YNY"),H&&(d.stateCode=H),d.countryCode=
# u?"US":d.country,f.OneTrust={geolocationResponse:d};e&&(e(I+b+".json","fetch",1),e(c,"script",1),e(I+"a8af1ce4-1c10-4813-9c94-a8a486b1256d/en.json","fetch",1));A(c,!0,function(){l.ut("gnt otsl");const b=w.head,c=b.appendChild,d=l.aeld;d("consent.onetrust",function(){var a=f.OnetrustActiveGroups;a&&",,"!==a&&(a=0>a.indexOf(",4,")||0>a.indexOf(",5,"),t.usp=a?"1YYY":"1YNY","googletag"in f&&googletag.apiReady&&(googletag.pubads().setPrivacySettings({restrictDataProcessing:a}),(f.adsbygoogle||(f.adsbygoogle=
# [])).requestNonPersonalizedAds=a?1:0))});b.appendChild=function(d){if(!m&&"onetrust-style"===d.id){const b=f.OneTrust&&OneTrust.IsAlertBoxClosedAndValid,c=l.ic.OptanonConsent&&b&&b(),e=l.de,h=e.dispatchEvent;m=d;l.ut("gnt otsa");e.dispatchEvent=function(b){B||"otloadbanner"!==b.type?h.call(e,b):(B=!0,a||!c?(h.call(e,b),a&&g()):n=b)};if(c)return}c.call(b,d)}},0,!0,a=>{a.setAttribute("data-domain-script",b);a.setAttribute("data-language","en")})}};A(q+"onetrust.com"+p,!0,0,function(){A(q+"1trust.app"+
# p,!0,0,t.otgc)})}
# {const a=g$.hp["gnt-dfp-xlabel"]||g$.qsp.usatl;gnt.x={initXCall:!0,acctId:"7103",acctName:"mi-freep-C1561",srvX:[{"cnt":1,"placement":"high_impact","bidPlacement":"high_impact","sizes":[[970,250],[970,90],[970,66],[728,90],[1,2],[2560,1440]],"unit":"7103/mi-freep-C1561/high_impact/news/politics","a9Slot":{"sizes":[[970,250],[728,90]]},"pbSlot":{"mediaTypes":{"banner":{"sizes":[[970,250],[728,90]]}},"bids":[{"bidder":"aol","params":{"s":[728,90],"placement":4113915,"alias":"7103/mi-freep-C1561/high_impact/news/politics","sizeId":"728x90","network":"10315.1","bidFloor":"0.0","server":"adserver.adtechus.com"}},{"bidder":"colossusssp","params":{"placement_id":21312}},{"bidder":"triplelift","params":{"s":[970,250],"inventoryCode":"USCP_970x250_desktop"}},{"bidder":"openx","params":{"s":[970,250],"unit":538809235,"delDomain":"gannett-d.openx.net"}},{"bidder":"rubicon","params":{"position":"atf","siteId":"37664","zoneId":156958,"inventory":{"topic":["Michigan Elections","Donald Trump","Elections","Joe Biden","Michigan Secretary of State's Office","U.S. Federal Court","Michigan Court of Appeals","Wayne County, MI"],"domain":["freep.com"],"section":["news"],"brandsafety":["custom-chaseunited","custom-facebook","custom-abbive","custom-quicken"],"subsection":["politics"]},"accountId":"11324"}},{"bidder":"criteo","params":{"networkId":1493}},{"bidder":"consumable","params":{"s":[970,250],"zoneIds":[188952],"unitName":"cnsmbl-audio-responsive","unitId":4605,"networkId":9969,"siteId":1035847}},{"bidder":"pubmatic","params":{"s":[970,250],"adSlot":"ROS@970x250","publisherId":"57752"}},{"bidder":"appnexus","params":{"s":[970,250],"placementId":10669873,"keywords":{"topic":["Michigan Elections","Donald Trump","Elections","Joe Biden","Michigan Secretary of State's Office","U.S. Federal Court","Michigan Court of Appeals","Wayne County, MI"],"position":"high_impact","section":["news"],"subsection":["politics"],"brandsafety":["custom-chaseunited","custom-facebook","custom-abbive","custom-quicken"]}}},{"bidder":"sonobi","params":{"ad_unit":"7103/mi-freep-C1561/high_impact/news/politics"}}]},"cfg":{"nolazy":true,"paramountEligible":true,"sizes":["970x250","970x90","970x66","728x90","1x2","2560x1440"]},"inxNm":"high_impact_970x250|728x90"},{"cnt":1,"placement":"teal-hero","bidPlacement":"preroll","id":"videoSlot","sizes":[],"unit":"7103/mi-freep-C1561/teal-hero/news/politics","a9Slot":{"mediaType":"video"},"pbSlot":{"mediaTypes":{"video":{"api":[1,2],"context":"instream","linearity":1,"maxduration":120,"minduration":0,"mimes":["application/javascript","video/mp4","video/webm","video/ogg","application/x-mpegURL","application/dash+xml","application/x-mpegurl","video/x-quicktime","video/ms-asf"],"size_id":201,"playerWidth":660,"playerHeight":372,"playerSize":[660,372],"protocols":[2,3,4,5,6,7,8]}},"bids":[{"bidder":"indexExchange","params":{"video":{"playerType":"HTML5","mimes":["application/javascript","video/mp4","video/webm","video/ogg","application/x-mpegURL","application/dash+xml","application/x-mpegurl","video/x-quicktime","video/ms-asf"],"api":[1,2],"siteId":239824,"minduration":0,"maxduration":120,"protocols":[2,3,4,5,6,7,8]},"siteId":239824,"id":1,"size":[660,372]}},{"bidder":"trustx","params":{"uid":"20395","keywords":{"topic":["Michigan Elections","Donald Trump","Elections","Joe Biden","Michigan Secretary of State's Office","U.S. Federal Court","Michigan Court of Appeals","Wayne County, MI"],"brandsafety":["custom-chaseunited","custom-facebook","custom-abbive","custom-quicken"]}}},{"bidder":"spotx","params":{"channel_id":232953,"ad_unit":"instream"}},{"bidder":"oneVideo","params":{"pubId":"Gannett","video":{"playerHeight":372,"api":[1,2],"protocols":[2,3,5,6],"mimes":["application/javascript","video/mp4","video/webm","video/ogg","application/x-mpegURL"],"playerWidth":660}}},{"bidder":"openx","params":{"video":{"url":"https://freep.com/story/news/politics/elections/2020/11/15/donald-trump-losing-michigan-lawsuits/6269524002/"},"unit":539725894 ...
# pbjs:{q:[],vIds:{"sonobi":3353351,"aol":3351817,"colossusssp":6745978,"triplelift":2615974,"openx":3355968,"rubicon":3342134,"criteo":3347031,"consumable":9330414,"pubmatic":2616245,"appnexus":3353552,"trustx":6745584,"spotx":6700167,"oneVideo":3352257},bidTO:1600},a9:{q:[]},inx:{q:[]},ias:{q:[],pubId:"922805"},gpt:{},vpc:[],nh:100,
# xlbl:a?[a]:[],waitGsp:[],
# xd:0,hlsUrl:"https://www.freep.com/gannett-web/apps/teal/dist/vendor/hls/hls.0.14.9.min.js",videoAds:{}}}
# (function(){function a(){;++d.xd;}function e(a,b,c){const v=[];for(const d of a)(d.bidder===b||c&&-1===b.indexOf(d.bidder))&&v.push(d);return v}function c(){R&&(R=L(R));w.hnb&&d.ko||!F||F.l||(E(F),F.l=!0,U(F))}function h(a){p("gnt pbDataReady");d.initXCall&&(z.dataRet=a,E(z.q),U(z.q))}function k(a){p("gnt a9DataReady");
# d.initXCall&&(D.dataRet=a,E(D.q),U(D.q))}function b(){p("gnt a9Ready");window.apstag&&apstag.init&&apstag.fetchBids&&(L(D.timeout),D.ready=!0,D.timedOut=!1,apstag.init({pubID:"3062",bidTimeout:1500,params:{us_privacy:gnt.usp}}),d.initXCall&&apstag.fetchBids({slots:Z},k))}function g(a){p("gnt inxDataReady");x.dataTimeout&&(x.dataTimeout=L(x.dataTimeout));x.dataRet||(x.dataRet={slot:d.initXCall&&a.slot&&
# a.slot||{},page:a.page&&a.page||[]});d.initXCall&&E(x.q)}function n(a){p("gnt iasDataReady");L(y.dataTimeout);y.dataTimedOut=!1;try{y.dataRet=Y(a)}catch(ha){}d.initXCall&&E(y.q)}function B(){;z.timeout=K(()=>{z.timedOut=!0},2E3);D.timeout=K(()=>{D.timedOut=!0},2E3);x.timeout=K(()=>{x.timedOut=!0},2E3);y.timeout=K(()=>{y.timedOut=!0},2E3);;if(!m["gnt-disable-gpt"]){;if(d.ol=!l.e&&(!w.bn||
# !w.bn.id||w.bn.h)&&d.olu){let a;const b=XMLHttpRequest.prototype,{send:c,open:e}=b,f=Symbol("url");b.open=function(...b){const c=b[1];!a&&"string"===typeof c&&0===c.indexOf("https://securepubads.g.doubleclick.net/gampad/ads")&&-1<c.indexOf("leaderboard_btf")&&(this[f]=d.cgu=c);e.apply(this,b)};b.send=function(...b){const v=this;if(!a&&v[f]){a=!0;const b=v.onload;v.onload=function(...a){d.xr&&d.xr(v);b.apply(v,a)}}c.apply(v,b)}};N("https://securepubads.g.doubleclick.net/tag/js/gpt.js",
# !0,null,a)};!m["gnt-disable-pbjs"]&&N('/tangstatic/js/pbjsandwich-q1a2z303b70f65.min.js',!0,null,()=>{z.fail=!0;E(z.q)});!m["gnt-disable-a9"]&&N("https://c.amazon-adsystem.com/aax2/apstag.js",!0,b,()=>{D.fail=!0;E(D.q);a()});!m["gnt-disable-inx"]&&N("https://js-sec.indexww.com/ht/p/184808-89514051626416.js",!0,null,()=>{x.fail=!0;E(x.q);a()});!m["gnt-disable-ias"]&&N("https://static.adsafeprotected.com/iasPET.1.js",!0,null,()=>{y.fail=!0;E(y.q);a()});!m["gnt-disable-confiant"]&&
# N("https://confiant-integrations.global.ssl.fastly.net/r5TdgVvkbv-PeaJCKaQfCh5Xsto/gpt_and_prebid_v3l/config.js",!0,null,a);}const {hp:m,qsp:q,ut:p,ic:t,b:l,ec:A}=g$,w=gnt;var {data:{pageAbVariant:f}}=w;const d=w.x,{acctId:u,acctName:C,srvX:H,waitGsp:F,videoAds:I,pbjs:z,a9:D,ias:y,inx:x}=d;var O=w.u,G=m["gnt-dfp-acctid"]||q.usatai;const J=("7070"===G||"7103"===G)&&G,Q=m["gnt-dfp-market"]||q.usatan,Y=JSON.parse,K=setTimeout,L=clearTimeout,M=document,aa=location.hostname;G=t.gnt_sb;
# const V=t.gnt_ub;let ba=0,ca=0,R;d.up=(q.itm_source||q.utm_source||"")+"|"+(q.itm_medium||q.utm_medium||"")+"|"+(q.itm_campaign||q.utm_campaign||"");d.vr=(f||"")+(G?f?",sb"+G:"sb"+G:"")+(V?G||f?",ub"+V:"ub"+V:"");m["gnt-disable-ccpa"]||(frames.__uspapiLocator||(f=M.createElement("iframe"),f.style.display="none",f.name="__uspapiLocator",M.body.appendChild(f)),addEventListener("message",function(a){const b=a&&a.data&&a.data.__uspapiCall;b&&__uspapi(b.command,b.version,(c,d)=>{a.source.postMessage({__uspapiReturn:{returnValue:c,
# success:d,callId:b.callId}},a.origin)})},!1));googletag={cmd:[function(){d.gpt.ready=!0;googletag.pubads().disableInitialLoad();p("gnt gptReady")}]};;__iasPET={queue:[()=>{p("gnt iasReady");y.timeout&&L(y.timeout);y.ready=!0;y.dataTimeout=K(()=>{y.dataTimedOut=!0},1600);__iasPET.pubId="922805";__iasPET.queue.push({adSlots:da,dataHandler:n});N("https://static.adsafeprotected.com/iasADX.js",!0,function(){window.__iasADX&&
# __iasADX.start(922805)},a)}]};headertag={cmd:[()=>{p("gnt inxReady");x.ready=!0;L(x.timeout);x.timedOut=!1;headertag.setSiteKeyValueData({topic:'elections',section:'news',subsection:'politics',brandSafety:"custom-chaseunited,custom-facebook,custom-abbive,custom-quicken",domain:w.data.publicationDomain});headertag.retrieveDemand(ea,g);x.dataRet||(x.dataTimeout=K(()=>{x.dataRet={slot:{},page:[]};E(x.q)},1E3))}]};confiant={enable_integrations:["gpt"],callback:(...a)=>{d.ccb.apply(a)}};
# ;let T;if(w.storage&&!(T=d.sGrp=localStorage.getItem("dfp_split_test_grp")))try{localStorage.setItem("dfp_split_test_grp",T=d.sGrp=String.fromCodePoint(97+Math.floor(4*Math.random())))}catch(v){};d.xFetch=function(a,b){var c=M.referrer;const e=t.last_front,v=d.up,f=b&&b.gntOvr;;f&&(a=a.replace("cust_params=","cust_params="+A("utm_props="+v+"&navigationtype="+
# (q.navigationtype||-1<c.indexOf(aa)?"internal":c?"external":"direct")+(e?"&front="+e:"")+(T?"&sgrp="+T:"")+"&")),c=m["gnt-dfp-xlabel"]||q.usatl,Q||c||J)&&(Q&&(a=a.replace(C,Q)),J&&(a=a.replace(u,J)),c&&(a=a.replace("cust_params=","cust_params="+A("adlabel="+c+"&"))));;return fetch(a,b).then(a=>{if(a.ok)return a.text();throw Error("xFetch returned status: ",a.status);})};const E=d.execQ=function(a){for(const b of a)if(b)try{b()}catch(ia){}},U=d.pushifyQ=function(a){a.push=a=>{if(a)try{a()}catch(ia){}}};
# ;
#   gnt.x.updatePbPlayerSize=function(a,c,d){pbjs.removeAdUnit(a.code);var {video:b}=a.mediaTypes;b.playerWidth=c;b.playerHeight=d;b.playerSize=[c,d];a.sizes=[[c,d]];for(const e of a.bids){({bidder:b}=e);const {video:a}=e.params;"oneVideo"===b?(a.playerWidth=c,a.playerHeight=d):"pubmatic"===b&&(a.w=c,a.h=d)}pbjs.addAdUnits(a)};
#
# gnt.x.sxu=function(d,e){const a=gnt.data,{userGsp:b,vr:c}=gnt.x;return d+encodeURIComponent("&aam_props="+a.adAamProps+"&build="+a.adBuild+(c?"&variant="+c:"")+(e&&void 0!==b?"&user_gsp="+b:""))+(gnt.u.co?"&rdp=1":"")+"&tfcd=0&c="+Math.floor(1E15*Math.random())};
# ;if(!m["gnt-disable-x"]&&!O.adfree){var S=d.slots={},{addScript:N}=gnt;f=!!l.m;;var fa=[],Z=[],ea=[],da=[],W=m["gnt-only-pb"],X=m["gnt-disable-pb"]&&m["gnt-disable-pb"].split(",");O.rs||((d.userGsp=t.user_gsp)||O.co?c():(O=t.__gads,R=K(c,2E3),d.xFetch('https://securepubads.g.doubleclick.net/gampad/adx?iu=%2F7103%2Fswg%2Fpts_mi-freep-C1561&sz=1x1&ref='+
# A(M.referrer)+"&cookie="+(O?A(O):"")+"&u_tz=-"+(new Date).getTimezoneOffset(),{credentials:"include",cache:"no-store"}).then(a=>{if(a.length){p("gnt gspDataLoaded");try{const b=Y(a),c=b&&b.value;void 0!==c&&(d.userGsp=c+"",M.cookie="user_gsp="+c+";path=/;secure;samesite=lax;priority=high;max-age=2592000")}catch(ha){}}R&&c()}).catch(a=>{c()})));;;d.olu='7103/mi-freep-C1561/consumer_sales-overlay/news/politics';;
# if(J)for(var P of M.querySelectorAll('[id*="ad-slot-"]'))P.id=P.id.replace(u,J);P=d.setupSrvX=function(a){const {cfg:b={},placement:c,sizes:f,cnt:h,pbSlot:g,id:k}=a,{isVideo:v,autoplay:n}=b;;const m=!b.nobid,t=m&&{htSlotName:a.inxNm};;a.cfg=b;v&&!I[c]&&(I[c]=a);;!v&&m&&ea.push(t);if(W||X){var p=g.bids;g.bids=W&&e(p,W)||X&&e(p,X,!0)};v||(J&&(a.unit=a.unit.replace(u,J)),Q&&(a.unit=a.unit.replace(C,
# Q)));let l;for(let e=0,q;e<h;e++){v?ca++:ba++;q=k&&k+ca||"ad-slot-"+(J||u)+"-"+C+"-"+c+"-news-politics-"+(b&&b.gallery&&"1"||ba);l=S[q]=Object.create(a);;if(m){if(!v||n){p=Object.create(g);const b=Object.assign({},a.a9Slot);p.code=b.slotID=q;fa.push(l&&(l.pbSlot=p)||p);Z.push(l&&(l.a9Slot=b)||b)}if(v)continue;l.inxSlot=t}da.push(l.iasSlot={adSlotId:q,size:f[0],adUnitPath:l.unit});l.lastBidTarg=[];;l.slotId=q;"high_impact"===
# c&&(d.hiSlotId=q)&&(l.isHi=!0);"poster_scroll"!==c&&"poster_scroll_front"!==c||(d.psId=q);l.adCount=e+1}return l};;for(const a of H)P(a);;pbjs={que:[function(){p("gnt pbReady");const a=pbjs;z.ready=!0;L(z.timeout);z.timedOut=!1;a.aliasBidder("appnexusAst",
# "appnexus");a.aliasBidder("ix","indexExchange");a.setConfig({rubicon:{singleRequest:!0},consentManagement:{usp:{cmpApi:"iab",timeout:0}},cache:{url:"https://prebid.adnxs.com/pbc/v1/cache"},mediaTypePriceGranularity:{"video":{"buckets":[{"max":20,"precision":2,"increment":0.1,"min":0},{"max":25,"precision":2,"increment":0.25,"min":20},{"max":30,"precision":2,"increment":0.5,"min":25},{"max":50,"precision":2,"increment":1,"min":30}]},"banner":{"buckets":[{"max":10,"precision":2,"increment":0.01,"min":0.1},{"max":20,"precision":2,"increment":0.05,"min":10},{"max":50,"precision":2,"increment":0.1,"min":20},{"max":75,"precision":2,"increment":0.25,"min":50},{"max":100,"precision":2,"increment":0.5,"min":75},{"max":200,"precision":2,"increment":1,"min":100},{"max":480,"precision":2,"increment":5,"min":200}]}},enableSendAllBids:!0,maxRequestsPerOrigin:1,timeoutBuffer:400,userSync:{syncEnabled:!0,
# filterSettings:{iframe:{bidders:['colossusssp'],filter:"exclude"},image:{bidders:['colossusssp'],filter:"exclude"}},syncsPerBidder:50}});;a.addAdUnits(fa);d.initXCall&&a.requestBids({bidsBackHandler:h,timeout:z.bidTO})}]};;googletag.cmd.push(()=>{let a,b,c,d,e=googletag.pubads();e.enableSingleRequest();e.setTagForChildDirectedTreatment(0);googletag.enableServices();for(a in S)S.hasOwnProperty(a)&&!S[a].cfg.isVideo&&(b=S[a],b.gptSlot=c=googletag.defineSlot(b.unit,b.sizes,a),c.addService(e),c.setTargeting("position",b.placement),b.adCount&&c.setTargeting("adCount",b.adCount),b.cfg.nolazy&&(m["gnt-x-showload"]&&
# (d=M.getElementById(a))&&(d.style.backgroundColor="blue"),googletag.display(a)))});;;m["gnt-delay-x"]?K(B,1E3):B()}})();;(gnt.v.tb=[{"container":"gnt_tbw_1","mode":"thumbnails-feed-desktop-03","placement":"Below Article Feed - Feed Redesign"},{"container":"gnt_tbw_2","mode":"organic-thumbnails-rr-stream","placement":"Right Rail Article Thumbnails - Redesign"}]).o=g$.hp["gnt-enable-tbo"];;;
# if(!g$.hp['gnt-disable-ht']){;;let r=document.referrer,o=location.origin;if(r=0===r.indexOf(o)&&r.substr(o.length)){let a;(a=r.indexOf("?"))&&-1<a&&(r=r.substr(0,a));(a=r.indexOf("#"))&&-1<a&&(r=r.substr(0,a))}
# if("/"===r||"/news/"===r||"/sports/"===r||"/entertainment/"===r||"/money/"===r)setTimeout(function(){;gnt.addScript("https://c2.taboola.com/nr/gannettcompany-freep/newsroom.js",!0,function(){g$.ut("gnt tbhtCb")})});;};;;
# {const a=gnt.u;a.getUser();if(a.au){const e=document.querySelector(".gnt_n_us_a");e&&(e.href="https://account."+gnt.data.publicationDomain,a.wn&&e.setAttribute("aria-label","Hi, "+a.wn));}};
# {const a=g$,e=a.vv,c=a.cached,h=a.el.debounce(()=>{c.windowInnerWidth=innerWidth;c.windowInnerHeight=innerHeight;for(const c of a.rh)c()});addEventListener("resize",h);e&&e.addEventListener("resize",h);a.rh=new Set};;;gnt.v.ua={c:{"appKey":"5s4510BYTB6aYwl-PUBGEA","token":"MTo1czQ1MTBCWVRCNmFZd2wtUFVCR0VBOmhRdFQ2cXA3Rmc0N2M4Tk9BQzl2R0NRLWU3aGxod3M5SGNSQnJVcUotRkE","vapidPublicKey":"BCdvC44aA3t7Iy5tWjAAxK-jLg3_CsiAHsZxKR0_CAcfe8-2Q_f8duMsFWskt2BB9tfhsUfeW5EBK_lC-fxB1sg="},p:2};;gnt.tmpl={navgd:{url:"/global-q1a2z3AH9tLAd6pCpE1EmjKwA0JxpL0+U.min.json",fb:"<div data-g-r=nav_fm style='padding:32px 32px 0 0;font:700 20px/24px \"Unify Sans\",\"Helvetica Neue\",\"Arial Nova\",Helvetica,Arial,sans-serif'>The navigation could not be loaded.</div><div data-g-r=nav_fm style='padding:18px 32px 18px 0;font:16px/18px \"Helvetica Neue\",\"Arial Nova\",Helvetica,Arial,sans-serif'>Please check your internet connection and try again."}};;
# g$.hp["gnt-disable-anc"]||(g$.el.loadAnc=function(){function b(){e.gannett={atoms:{setup:{camId:g$.ic.cam_eid||"control",environment:c,gup_lng:a.lng,platform:"tangent",siteCode:"PDTF",ssts:"news/politics/elections",taxonomy:["Michigan Elections","Donald Trump","Elections","Joe Biden","Michigan Secretary of State's Office","U.S. Federal Court","Michigan Court of Appeals","Wayne County, MI"],user:a.user,analytics:{newslettersignupcta:function(a){gnt.a7s.tq.push({et:"custom",
# ca:gnt.data.a7sPre+"|"+a})}}}}};g$.require({url:f,co:!0}).then(function(){const {FontFace:a,customElements:b}=e;a&&document.fonts.add(new a("Gannett Atoms Components Unify Serif","local(Georgia Pro),local(Georgia),local(Droid Serif)"));b&&b.define("gannett-atoms-component-ui-font-loader",class extends HTMLElement{connectedCallback(){this.style.display="none"}})})}const d=g$.preload,a=gnt.u,e=window,c="stage"===g$.hp["gnt-test-ancenv"]?"stage":"prod",g="https://atoms.freep.com",
# f=g+"/atoms-library/"+c+"/dist/gannett-atoms-library.js";d(f,void 0,1);d(g+"/atoms-components/"+c+"/dist/gannett-atoms-components/gannett-atoms-components.esm.js",void 0,1);d("https://user.freep.com/PDTF-GUP/user/newsletters/","fetch","use-credentials");a.user&&!a.user.local?b():a.getUser().then(b,b)});
#
#         if(0===document.referrer.indexOf(location.origin)){let b,d;for(let a=0,e=document.querySelectorAll("[data-g-r~=base_xbutton]"),f=e.length;a<f;a++)Object.defineProperty(e[a],"href",{configurable:!0,enumerable:!0,get:function(){if(!d){d=!0;const a=sessionStorage.previousFront;if(a)try{const c=JSON.parse(a);c&&(b=c.path)}catch(c){}}b&&this.setAttribute("href",b);Object.defineProperty(this,"href",{configurable:!0,enumerable:!0,value:b||this.getAttribute("href")})}})};
#
#       gnt.data.sfPath="/tangstatic/html/pdtf/sf-q1a2z3be0d353f.min.html";
#   g$.run.push(function(){g$.registerMod("vp");;g$.hp["gnt-disable-autoplay"]||g$.el.trigger("vp_ap",document.documentElement);});
#
#
#   ;
# gnt.data.tVPS={vIas:"/gannett-web/apps/teal/dist/vendor/ias/ias-3.5.1.min.js",vIma3:"https://imasdk.googleapis.com/js/sdkloader/ima3.js",vIIma:"/gannett-web/apps/teal/dist/teal-ima-a1174258.min.js",vCs:"/gannett-web/apps/teal/dist/vendor/comscore/streamsense-5.1.1.160316.min.js",vICs:"/gannett-web/apps/teal/dist/teal-comscore-f1701de9.min.js",vIGa:"/gannett-web/apps/teal/dist/teal-gcianalytics-91a8d9d5.min.js",vHls:"/gannett-web/apps/teal/dist/vendor/hls/hls.0.14.9.min.js",vIHls:"/gannett-web/apps/teal/dist/teal-hls-ec6a0617.min.js",
# tEncore:"/gannett-web/apps/teal/dist/encore-c29e248c.min.js",tShare:"/gannett-web/apps/teal/dist/share-454f9438.min.js",tCntrls:"/gannett-web/apps/teal/dist/controls-a72d7ef9.min.js",tP:"/gannett-web/apps/teal/dist/tealplayer-0d1d8d46.min.js"};
#
#
#   if(g$.b.i||-1<g$.ua.indexOf("Safari")&&0>g$.ua.indexOf("Chrome")){const a=g$.aeld;a("webkitfullscreenchange",function(){g$.d.querySelector(".gnt_cw_w,.gnt_cw").style[g$.d.webkitFullscreenElement?"setProperty":"removeProperty"]("isolation","auto")})};
#
# ;g$.ut("gnt bodyendDone");</script><script async="" onerror="document.querySelectorAll('.gnt__hbd').forEach(e=&gt;e.classList.remove('gnt__hbd'))" src="/tangstatic/js/main-q1a2z3bca813c2.min.js"></script><script data-tmpl-key="navgdp" type="gnt/tmpl"><div class="gnt_n_dd_oy gnt_n_dd__sz" data-g-r=nav_oy></div><div class="gnt_n_dd gnt_n_dd__sz" data-g-r="nav_dd nav_te nav_ff" tabindex=0></div>|styles|[data-g-s=nav_ao] .gnt_n_dd_bt_svg{transform:rotate(180deg);background:currentColor;fill:#303030}.gnt_n_dd_oy{display:none;left:0;right:0;height:calc(var(--gnt-vh,100vh) - 100px - var(--gnt-sh,0px))}.gnt_n_dd{overscroll-behavior-y:contain;overflow:auto;overflow-x:hidden;box-sizing:border-box;display:none;width:385px;height:calc(var(--gnt-vh,100vh) - 100px - var(--gnt-sh,0px));margin:0 0 0 -20px;padding:7px 20px 0 32px;border-top:5px solid #0098fe;background:#303030;color:#fff}[data-g-s=nav_ao] .gnt_n_dd__sz{display:block;position:absolute}</script><script data-tmpl-key="navse" type="gnt/tmpl"><form class=gnt_n_se_fm data-g-r=nav_dd action=/search/ role=search><input class=gnt_n_se_fm_qr data-g-r=nav_pf name=q placeholder="What can we help you find?" mozactionhint=search enterkeyhint=search aria-label="Search query"/><button class=gnt_n_se_fm_sm data-t-l=${se}|H1Nav|search| aria-label=Submit><svg class=gnt_n_se_fm_sm_svg viewBox="0 0 18 18"><path d="M12.28 9.76H2V7.74h10.28l-2.23-2.31L11.43 4 16 8.75l-4.57 4.75-1.38-1.43 2.23-2.31z"/></svg></button></form>|styles|.gnt_n_se_fm{display:none;align-items:center;justify-content:center;position:absolute;left:0;right:0;height:180px;padding:0 0 15px;border-top:5px solid #0098fe;background:#303030}[data-g-s~=nav_ao] .gnt_n_se_fm{display:flex}.gnt_n_se_fm_qr{width:492px;height:46px;padding:0 50px 0 0;border-style:solid;border-width:0 0 2px;border-color:#fff;border-radius:0;outline:0;background:0 0;color:#fff;font:700 28px 'Unify Sans','Helvetica Neue','Arial Nova',Helvetica,Arial,sans-serif}.gnt_n_se_fm_qr::placeholder{opacity:1;color:#fff}.gnt_n_se_fm_qr:-webkit-autofill{box-shadow:inset 0 46px #303030;-webkit-text-fill-color:#fff}.gnt_n_se_fm_sm{width:60px;height:50px;border:0;margin:0 -15px 0 -45px;padding:0;outline-offset:-8px;fill:#fff;background:0 0;cursor:pointer}.gnt_n_se_fm_sm:hover{fill:#e0e0e0}.gnt_n_se_fm_sm_svg{width:42px;height:42px;margin-top:3px;stroke:#303030;stroke-width:.5px}</script><script data-tmpl-key="navus" type="gnt/tmpl"><div class=gnt_n_us_dd data-g-r=nav_dd><div class=gnt_n_us_dd_u><a class=gnt_n_us_dd_a href=https://account.freep.com/ data-t-l="|H1Nav|account|manage account">Manage Account</a> <a class=gnt_n_us_dd_a data-u-sr="anon sub" href=https://user.freep.com/user/enewspaper data-t-l=|H1Nav|account|e-edition>E-Edition</a> <a class=gnt_n_us_dd_a href=https://profile.freep.com/newsletters/manage/ data-t-l=|H1Nav|account|newsletters>Newsletters</a> <a class=gnt_n_us_dd_a data-u-sr="anon sub" href=https://account.freep.com/pay data-t-l="|H1Nav|account|pay bill">Pay Bill</a> <a class=gnt_n_us_dd_a data-u-sr="anon sub" href=https://account.freep.com/delivery-issue data-t-l="|H1Nav|account|report delivery issues">Report Delivery Issues</a> <a class=gnt_n_us_dd_a data-u-sr="anon sub" href=https://account.freep.com/delivery-temporary-stop data-t-l="|H1Nav|account|pause delivery">Pause Delivery</a> <a class=gnt_n_us_dd_a data-u-sr="anon sub" href=https://cm.freep.com/subscriberguide data-t-l="|H1NavTree|account|subscriber guide">Subscriber Guide</a> <a class=gnt_n_us_dd_a href=https://help.freep.com data-t-l="|H1Nav|account|help center">Help Center</a> <a class="gnt_n_us_dd_a gnt_n_us_dd_a__li" data-u-sr="reg sub" href="https://user.freep.com/PDTF-GUP/user/logout/?return-url=https%3A%2F%2Fwww.freep.com%2Fstory%2Fnews%2Fpolitics%2Felections%2F2020%2F11%2F15%2Fdonald-trump-losing-michigan-lawsuits%2F6269524002%2F" data-t-l="|H1Nav|account|sign out">Sign Out</a></div><div class=gnt_n_us_dd_ac data-u-sr="anon reg"><div class=gnt_n_us_dd_lbl data-u-sr=anon>Have an existing ...

# %%
article = soup.find('div', class_ = 'gnt_ar_b')

article.text
# Out:
# 'LANSING — Lawsuits\xa0filed in the wrong courts.Naming the wrong defendants.Alleging\xa0facts with no connection\xa0to the defendants being sued.Forces backing Republican President Donald Trump have filed at least five lawsuits in state and federal courts in Michigan\xa0seeking to delay or stop the state\'s certification of 16 electoral votes for Democratic\xa0President-elect Joe Biden.With every Michigander\'s vote cast and counted in the presidential contest, showing Biden defeating Trump by close to 150,000 votes according to the unofficial tally,\xa0elections workers\xa0statewide are now undertaking the tedious process of officially certifying the vote and converting the state\'s popular vote into the state\'s Electoral College votes. That process relies on local and state election officials meeting a series of tight deadlines and fulfilling their legal duties. And derailing this process appears to be a goal the lawsuits all share.The suits could create\xa0significant complications if they produced\xa0court orders delaying certification of election results in key\xa0Michigan counties beyond Tuesday\'s deadline,\xa0or dragged out thecertification of statewide results beyond the Dec. 8 "safe harbor" date by which Congress is required to accept Michigan\'s electoral votes.But the suits have been marked by\xa0unusual legal missteps and repeated judicial setbacks. Some analysts say it is difficult to discern a coherent strategy, other than to seek to undermine overall confidence in the elections process.“I’ve heard some folks describing it as throwing a lot of stuff against the wall and hoping something sticks. It seems to be instead throwing nothing against the wall and hoping something sticks,” said Steven Liedel, a Lansing\xa0attorney who counts state constitutional law among his specialties and served as chief counsel to former Democratic Gov. Jennifer Granholm."I think some judges ought to start issuing some sanctions" against attorneys filing the suits, said Bob LaBrant, a longtime GOP strategist and former general counsel for the Michigan Chamber of Commerce.In the five lawsuits filed since the election:The injunctions or other requested relief\xa0were\xa0quickly rejected\xa0by judges in three of the cases, though some appeals are pending.Michigan Court of Claims Judge Cynthia Stephens, in a Nov. 6 ruling that rejected the Trump campaign\'s call for a halt to the counting of absentee ballots in Detroit, said key allegations in the suit were inadmissible hearsay and the campaign wrongly sued Secretary of State Jocelyn Benson over issues controlled not by her, but by local officials.When it first sought to appeal Stephens\' ruling, the Trump campaign was told by the Michigan Court of Appeals that its submission was rejected as "defective" because it lacked four required documents, including a copy of\xa0 Stephens\'\xa0order it sought to appeal.In dismissing a suit Friday brought by\xa0activist lawyer David Kallman on behalf of two voters, Wayne County Circuit Judge Timothy Kenny said allegations in the suit were largely "generalized speculation" fueled by misinformation, or "simply are not credible" when balanced against other evidence.On Nov. 6, in denying an injunction requested in an earlier suit brought by the nonprofit Election Integrity Fund and Republican poll challenger Sarah Stoddard, Kenny again cited "mere speculation," the plaintiffs\' misunderstanding of state election law, and "no evidence to support accusations of voter fraud."Last Tuesday, the Trump campaign accidentally sued Secretary of State Jocelyn Benson in the U.S. Court of Claims, a court reserved for federal contract disputes, patent cases, Indian claims\xa0and suits related to military pay, among other items, but not election cases. The same suit was filed in the U.S. District Court for the Western District of Michigan, where it will now be decided.Though two of the\xa0five suits were successfully\xa0filed in federal court, none\xa0belong there, a ...

# %%
31
