# %%
import nltk

import acquire
import pandas as pd
import os
from bs4 import BeautifulSoup

import unicodedata
import re
import json

import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords

# %%
df = acquire.get_news_articles()

# %%
df
# Out:
#             topic                                              title  \
# 0        business  Moderna's early data shows its COVID-19 vaccin...
# 1        business  15 countries sign world's biggest free-trade p...
# 2        business  How does Moderna's COVID-19 vaccine candidate ...
# 3        business  Reliance Retail buys 96% stake in Urban Ladder...
# 4        business  Reduce foreign funding to 26% by Oct 15, 2021:...
# ..            ...                                                ...
# 94  entertainment  Aditya to start shooting for upcoming action f...
# 95  entertainment  Chadwick won't be digitally recreated for Blac...
# 96  entertainment  You have to follow the studio: Jude Law on Dep...
# 97  entertainment  Lost a family member: Satyajit Ray's son on So...
# 98  entertainment  Embassy of India in France pays tribute to Sou...
#
#                author                                            content
# 0      Pragya Swastik  American biotechnology company Moderna on Mond...
# 1      Pragya Swastik  Fifteen Asia-Pacific countries signed the Regi...
# 2      Pragya Swastik  Moderna's initial results of late-stage trial ...
# 3   Rishabh Bhatnagar  Reliance Industries' retail arm Reliance Retai...
# 4      Pragya Swastik  The I&B Ministry on Monday asked digital media...
# ..                ...                                                ...
# 94       Kriti Sharma  Actor Aditya Roy Kapur will start shooting for...
# 95       Kriti Sharma  When asked if Marvel will digitally recreate l...
# 96       Kriti Sharma  Actor Jude Law, who plays younger Albus Dumble...
# 97       Kriti Sharma  Following the demise of Bengali actor Soumitra...
# 98       Kriti Sharma  Embassy of India in France paid tribute to act...
#
# [99 rows x 4 columns]

# %% [markdown]
# 1. Define a function named basic_clean. It should take in a string and apply some basic text cleaning to it:
#
#     Lowercase everything
#
#     Normalize unicode characters
#
#     Replace anything that is not a letter, number, whitespace or a single quote.

# %%
# creating the function that does what is specified above

def basic_clean(string):
    string = string.lower()
    string = unicodedata.normalize('NFKD', string).encode('ascii', 'ignore')\
            .decode('utf-8', 'ignore')
    string = re.sub(r"[^a-z0-9\s\'']", '', string)
    
    return string

# %%
# checking if the function created above works
title = list(df.title.astype(str))
new_title= []
for item in title:
    new_title.append(basic_clean(item))

# %% [markdown]
# 2.Define a function named tokenize. It should take in a string and tokenize all the words in the string.

# %%
def tokenize(string):
    tokenizer = nltk.tokenize.ToktokTokenizer()
    string = tokenizer.tokenize(string, return_str = True)
    return string

# %%
# checking if the function created above works
title = list(df.title.astype(str))
new_title= []
for item in title:
    new_title.append(tokenize(item))

# %%
new_title
# Out:
# ["Moderna ' s early data shows its COVID-19 vaccine is 94.5 % effective",
#  "15 countries sign world ' s biggest free-trade pact which India left last year",
#  "How does Moderna ' s COVID-19 vaccine candidate compare to Pfizer ' s ?",
#  'Reliance Retail buys 96 % stake in Urban Ladder for ₹ 182 crore',
#  'Reduce foreign funding to 26 % by Oct 15 , 2021 : Govt to digital media',
#  "India ' s longest gas blaze burning in Assam oil well doused after 5 months",
#  'Traders record ₹ 72,000 cr Diwali sales , hand China loss of ₹ 40,000 cr : CAIT',
#  'Mahindra says he still wears a 1975 Kada blessed in Golden Temple ; shares pic',
#  "EU to buy 405 mn doses of CureVac ' s potential COVID-19 vaccine",
#  "Bharat Biotech ' s COVID-19 vaccine ' COVAXIN ' enters phase-3 trials",
#  "Telcos , IT firms object to TRAI ' s proposed cloud services regulation body",
#  "Software issue halts trading on Australia ' s stock exchange",
#  "' Absolutely not ' in talks to sell stake in Mitsubishi : Nissan COO",
#  'Nissan considering 34 % stake sale in Mitsubishi : Reports',
#  'Ola , Swiggy to put 5 % of wages in social security fund under draft rules : Report',
#  'UK to ban sale of new diesel , petrol cars from 2030 : Report',
#  'Wholesale price inflation rises to 1.48 % in Oct , reaches 8-month high',
#  'Japan exits COVID-19-induced recession with 5 % growth in Q3',
#  'Walmart nearly exits Japan after selling $ 1 bn-stake in retail chain Seiyu',
#  'Indian economy may be recovering faster than expected : Oxford Economics',
#  'Patanjali-owned Ruchi Soya to launch FPO next year',
#  "India ' s diesel sales fall 5 % y-o-y in first half of November",
#  'HDFC Mutual Fund appoints Navneet Munot as MD and CEO',
#  'Immigration officials stop businessman BR Shetty from flying to UAE',
#  'Tata Steel Q2 profit drops 63 % due to overseas losses',
#  'Olympic medalist working as delivery boy to generate income amid COVID-19',
#  "That was the best comment I saw whole day : Akash Ambani on Vaughan ' s tweet on MI",
#  "RCB issues clarification after Kohli called ' hypocrite ' for his Diwali message",
#  'McCullum trolls Lee over apology for 2011 bouncer that broke his nose',
#  "What are new changes made to T20 format in Australia ' s Big Bash League ?",
#  'Pic of foreign player wearing MI gloves while batting goes viral , PSL trolled',
#  'Please bowl slow to me next time : Afridi to Rauf after getting out for first-ball duck',
#  'Kohli always pushes the boundaries : Ex-Australia coach Lehmann',
#  "Wasim Jaffer trolls Australia ' s new T20 rules with ' Gangs of Wasseypur ' meme",
#  "Jimmy Neesham questions Big Bash League ' s ' X-factor Player ' rule",
#  'Ex-Bangladesh U-19 cricketer Mohammad Sozib dies by suicide aged 21',
#  'Rauf apologises to Afridi with folded hands after dismissing him for 1st ball duck',
#  'Gabon football team forced to sleep on airport floor , pics surface',
#  'Not pace but playing Rashid Khan was a big challenge : Padikkal',
#  'Rahul is one of the best white-ball players at the moment : Nasser',
#  'Tim Paine in self-isolation due to COVID-19 outbreak in Adelaide',
#  'Best series of my life : Tendulkar on 2001 India-Aus Test series',
#  'Australia to introduce pre-match anti-racism ritual with the India series',
#  "Maninder Singh , Chetan Sharma apply for national selectors ' post",
#  "Djokovic ends his sixth year as World No 1 , equals Sampras ' record",
#  'Former England and Liverpool goalkeeper Ray Clemence dies at 72',
#  'Special for us , witnessing history being made : Vettel to Hamilton',
#  'Good thing that Virat has a big say in Indian cricket : Greg Chappell',
#  'Ishant working with Mhambrey to become fit for Tests vs Aus : Reports',
#  'Hamilton ‘bursts into tears ’ after record-equalling 7th F1 title',
#  'SpaceX launches 4 astronauts on its first commercial crew flight for NASA',
#  "Who are the 4 astronauts on SpaceX ' s 1st commercial crew flight for NASA ?",
#  'Zoom meetings could be behind surge in demand for plastic surgery : Experts',
#  "Don ' t want to regulate , it ' s their responsibility : Govt on OTT platforms",
#  "4L malware , 375 cyberattacks seen daily : India ' s cybersecurity chief",
#  'Google tool lets users know how long their Photos storage will last',
#  'Virgin Galactic delays test flight due to lockdown in New Mexico',
#  'Microsoft advises users against using SMS for two-factor authentication',
#  'Amazon apologises for saying Northern Ireland is not part of UK',
#  "US says sharing other firms ' data with Google in lawsuit to weaken trust",
#  'Video games can be good for mental health : Oxford study',
#  "Software issue halts trading on Australia ' s stock exchange",
#  "17-yr-old Bangladeshi wins Children ' s Peace Prize for fighting cybercrime",
#  "Apple tells Mac users its anti-malware feature doesn ' t spy on them",
#  'Man loses ₹ 5.85L to cyber fraudsters claiming to update UPI account',
#  'Zoom to temporarily lift 40-minute call limit globally',
#  "Privacy activist group files complaints against Apple ' s tracking tool",
#  'Zoom Founder Eric Yuan invests in Bengaluru startup Arzooo',
#  'Finance ministry gives DGCA approval to set up Drones Directorate',
#  'Tesla opens its largest EV super-charging station in US',
#  'Facial recognition system to identify bears created',
#  'Tech firms could be banned if they breach rules : EU',
#  "SpaceX ' s Starlink users report internet speeds upto 200 Mbps",
#  'US President-elect Joe Biden congratulates SpaceX , NASA on launch',
#  "' Resident Evil ' game maker says data of over 3.5L customers stolen",
#  'Dwayne Johnson fails to get into Porsche for chase sequence in movie , shares pic',
#  "Govinda didn ' t visit when one of my twins was fighting for life : Nephew Krushna",
#  "I don ' t want my son to be a singer , at least not in India : Sonu Nigam",
#  "Big B shares fan-made collage showing Aaradhya ' s pics over 9 yrs on her b ' day",
#  "Big B ' s father ' s statue in Poland honoured with diya on Diwali , actor shares pic",
#  "Salman is everything to me : Amaal on trolling by his fans for saying he ' s SRK fan",
#  'Tamil TV series actor hacked to death , CCTV footage shows argument with gang',
#  "Zazie Beetz joins Brad Pitt in action film ' Bullet Train ' : Reports",
#  "Do something original : ' Home Alone ' director on Disney remakes",
#  "He was a gentle soul with abundant talent : Big B on Soumitra ' s demise",
#  "Justin Bieber , Jennifer Lopez win at People ' s Choice Awards 2020",
#  "He was one of my oldest friends : Sharmila on Soumitra ' s demise",
#  "Please don ' t visit to pay condolences : Soumitra ' s daughter amid COVID-19",
#  "Feel like you ' ve gone for a long shoot : Irrfan ' s son on late actor",
#  'Aditya made me feel comfortable on the sets of Ludo : Sanya Malhotra',
#  'My role in Laxmii was a cameo but it had a lot of emotions : Sharad',
#  'We decided to have the baby in Canada : Karanvir Bohra on third child',
#  "Matrix 4 breaks Germany ' s COVID-19 laws by hosting party : Reports",
#  'Women are not offered cliched roles like before : Samantha Akkineni',
#  "Aditya to start shooting for upcoming action film ' Om ' in December",
#  "Chadwick won ' t be digitally recreated for Black Panther sequel : Marvel",
#  "You have to follow the studio : Jude Law on Depp ' s Fantastic Beasts exit",
#  "Lost a family member : Satyajit Ray ' s son on Soumitra Chatterjee ' s demise",
#  'Embassy of India in France pays tribute to Soumitra Chatterjee']

# %% [markdown]
# 3. Define a function named stem. It should accept some text and return the text after applying stemming to all the words.

# %%
def stem(string):
    ps = nltk.porter.PorterStemmer()
    stems = [ps.stem(word) for word in string.split()]
    string_stemmed = ' '.join(stems)
    return string_stemmed

# %%
# checking if the function created above works
title = list(df.title.astype(str))
new_title= []
for item in title:
    new_title.append(stem(item))

new_title
# Out:
# ["moderna' earli data show it covid-19 vaccin is 94.5% effect",
#  "15 countri sign world' biggest free-trad pact which india left last year",
#  "how doe moderna' covid-19 vaccin candid compar to pfizer's?",
#  'relianc retail buy 96% stake in urban ladder for ₹182 crore',
#  'reduc foreign fund to 26% by oct 15, 2021: govt to digit media',
#  "india' longest ga blaze burn in assam oil well dous after 5 month",
#  'trader record ₹72,000 cr diwali sales, hand china loss of ₹40,000 cr: cait',
#  'mahindra say he still wear a 1975 kada bless in golden temple; share pic',
#  "EU to buy 405 mn dose of curevac' potenti covid-19 vaccin",
#  "bharat biotech' covid-19 vaccin 'covaxin' enter phase-3 trial",
#  "telcos, IT firm object to trai' propos cloud servic regul bodi",
#  "softwar issu halt trade on australia' stock exchang",
#  "'absolut not' in talk to sell stake in mitsubishi: nissan coo",
#  'nissan consid 34% stake sale in mitsubishi: report',
#  'ola, swiggi to put 5% of wage in social secur fund under draft rules: report',
#  'UK to ban sale of new diesel, petrol car from 2030: report',
#  'wholesal price inflat rise to 1.48% in oct, reach 8-month high',
#  'japan exit covid-19-induc recess with 5% growth in Q3',
#  'walmart nearli exit japan after sell $1 bn-stake in retail chain seiyu',
#  'indian economi may be recov faster than expected: oxford econom',
#  'patanjali-own ruchi soya to launch fpo next year',
#  "india' diesel sale fall 5% y-o-i in first half of novemb",
#  'hdfc mutual fund appoint navneet munot as MD and ceo',
#  'immigr offici stop businessman BR shetti from fli to uae',
#  'tata steel Q2 profit drop 63% due to oversea loss',
#  'olymp medalist work as deliveri boy to gener incom amid covid-19',
#  "that wa the best comment I saw whole day: akash ambani on vaughan' tweet on MI",
#  "rcb issu clarif after kohli call 'hypocrite' for hi diwali messag",
#  'mccullum troll lee over apolog for 2011 bouncer that broke hi nose',
#  "what are new chang made to t20 format in australia' big bash league?",
#  'pic of foreign player wear MI glove while bat goe viral, psl troll',
#  'pleas bowl slow to me next time: afridi to rauf after get out for first-bal duck',
#  'kohli alway push the boundaries: ex-australia coach lehmann',
#  "wasim jaffer troll australia' new t20 rule with 'gang of wasseypur' meme",
#  "jimmi neesham question big bash league' 'x-factor player' rule",
#  'ex-bangladesh u-19 cricket mohammad sozib die by suicid age 21',
#  'rauf apologis to afridi with fold hand after dismiss him for 1st ball duck',
#  'gabon footbal team forc to sleep on airport floor, pic surfac',
#  'not pace but play rashid khan wa a big challenge: padikk',
#  'rahul is one of the best white-bal player at the moment: nasser',
#  'tim pain in self-isol due to covid-19 outbreak in adelaid',
#  'best seri of my life: tendulkar on 2001 india-au test seri',
#  'australia to introduc pre-match anti-rac ritual with the india seri',
#  "manind singh, chetan sharma appli for nation selectors' post",
#  "djokov end hi sixth year as world No 1, equal sampras' record",
#  'former england and liverpool goalkeep ray clemenc die at 72',
#  'special for us, wit histori be made: vettel to hamilton',
#  'good thing that virat ha a big say in indian cricket: greg chappel',
#  'ishant work with mhambrey to becom fit for test vs aus: report',
#  'hamilton ‘burst into tears’ after record-equal 7th F1 titl',
#  'spacex launch 4 astronaut on it first commerci crew flight for nasa',
#  "who are the 4 astronaut on spacex' 1st commerci crew flight for nasa?",
#  'zoom meet could be behind surg in demand for plastic surgery: expert',
#  "don't want to regulate, it' their responsibility: govt on ott platform",
#  "4L malware, 375 cyberattack seen daily: india' cybersecur chief",
#  'googl tool let user know how long their photo storag will last',
#  'virgin galact delay test flight due to lockdown in new mexico',
#  'microsoft advis user against use sm for two-factor authent',
#  'amazon apologis for say northern ireland is not part of UK',
#  "US say share other firms' data with googl in lawsuit to weaken trust",
#  'video game can be good for mental health: oxford studi',
#  "softwar issu halt trade on australia' stock exchang",
#  "17-yr-old bangladeshi win children' peac prize for fight cybercrim",
#  "appl tell mac user it anti-malwar featur doesn't spi on them",
#  'man lose ₹5.85l to cyber fraudster claim to updat upi account',
#  'zoom to temporarili lift 40-minut call limit global',
#  "privaci activist group file complaint against apple' track tool",
#  'zoom founder eric yuan invest in bengaluru startup arzooo',
#  'financ ministri give dgca approv to set up drone director',
#  'tesla open it largest EV super-charg station in US',
#  'facial recognit system to identifi bear creat',
#  'tech firm could be ban if they breach rules: EU',
#  "spacex' starlink user report internet speed upto 200 mbp",
#  'US president-elect joe biden congratul spacex, nasa on launch',
#  "'resid evil' game maker say data of over 3.5l custom stolen",
#  'dwayn johnson fail to get into porsch for chase sequenc in movie, share pic',
#  "govinda didn't visit when one of my twin wa fight for life: nephew krushna",
#  "I don't want my son to be a singer, at least not in india: sonu nigam",
#  "big B share fan-mad collag show aaradhya' pic over 9 yr on her b'day",
#  "big b' father' statu in poland honour with diya on diwali, actor share pic",
#  "salman is everyth to me: amaal on troll by hi fan for say he' srk fan",
#  'tamil TV seri actor hack to death, cctv footag show argument with gang',
#  "zazi beetz join brad pitt in action film 'bullet train': report",
#  "Do someth original: 'home alone' director on disney remak",
#  "He wa a gentl soul with abund talent: big B on soumitra' demis",
#  "justin bieber, jennif lopez win at people' choic award 2020",
#  "He wa one of my oldest friends: sharmila on soumitra' demis",
#  "pleas don't visit to pay condolences: soumitra' daughter amid covid-19",
#  "feel like you'v gone for a long shoot: irrfan' son on late actor",
#  'aditya made me feel comfort on the set of ludo: sanya malhotra',
#  'My role in laxmii wa a cameo but it had a lot of emotions: sharad',
#  'We decid to have the babi in canada: karanvir bohra on third child',
#  "matrix 4 break germany' covid-19 law by host party: report",
#  'women are not offer clich role like before: samantha akkineni',
#  "aditya to start shoot for upcom action film 'om' in decemb",
#  "chadwick won't be digit recreat for black panther sequel: marvel",
#  "you have to follow the studio: jude law on depp' fantast beast exit",
#  "lost a famili member: satyajit ray' son on soumitra chatterjee' demis",
#  'embassi of india in franc pay tribut to soumitra chatterje']

# %% [markdown]
# 4. Define a function named lemmatize. It should accept some text and return the text after applying lemmatization to each word.

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/bibekmainali/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
def lemmatize(string):
    wnl = nltk.stem.WordNetLemmatizer()
    lemmas = [wnl.lemmatize(word) for word in string.split()]
    string_lemmatized = ' '.join(lemmas)
    
    return string_lemmatized

# %%
# checking if the function created above works
title = list(df.title.astype(str))
new_title= []
for item in title:
    new_title.append(lemmatize(item))

new_title
# Out:
# ["Moderna's early data show it COVID-19 vaccine is 94.5% effective",
#  "15 country sign world's biggest free-trade pact which India left last year",
#  "How doe Moderna's COVID-19 vaccine candidate compare to Pfizer's?",
#  'Reliance Retail buy 96% stake in Urban Ladder for ₹182 crore',
#  'Reduce foreign funding to 26% by Oct 15, 2021: Govt to digital medium',
#  "India's longest gas blaze burning in Assam oil well doused after 5 month",
#  'Traders record ₹72,000 cr Diwali sales, hand China loss of ₹40,000 cr: CAIT',
#  'Mahindra say he still wear a 1975 Kada blessed in Golden Temple; share pic',
#  "EU to buy 405 mn dos of CureVac's potential COVID-19 vaccine",
#  "Bharat Biotech's COVID-19 vaccine 'COVAXIN' enters phase-3 trial",
#  "Telcos, IT firm object to TRAI's proposed cloud service regulation body",
#  "Software issue halt trading on Australia's stock exchange",
#  "'Absolutely not' in talk to sell stake in Mitsubishi: Nissan COO",
#  'Nissan considering 34% stake sale in Mitsubishi: Reports',
#  'Ola, Swiggy to put 5% of wage in social security fund under draft rules: Report',
#  'UK to ban sale of new diesel, petrol car from 2030: Report',
#  'Wholesale price inflation rise to 1.48% in Oct, reach 8-month high',
#  'Japan exit COVID-19-induced recession with 5% growth in Q3',
#  'Walmart nearly exit Japan after selling $1 bn-stake in retail chain Seiyu',
#  'Indian economy may be recovering faster than expected: Oxford Economics',
#  'Patanjali-owned Ruchi Soya to launch FPO next year',
#  "India's diesel sale fall 5% y-o-y in first half of November",
#  'HDFC Mutual Fund appoints Navneet Munot a MD and CEO',
#  'Immigration official stop businessman BR Shetty from flying to UAE',
#  'Tata Steel Q2 profit drop 63% due to overseas loss',
#  'Olympic medalist working a delivery boy to generate income amid COVID-19',
#  "That wa the best comment I saw whole day: Akash Ambani on Vaughan's tweet on MI",
#  "RCB issue clarification after Kohli called 'hypocrite' for his Diwali message",
#  'McCullum troll Lee over apology for 2011 bouncer that broke his nose',
#  "What are new change made to T20 format in Australia's Big Bash League?",
#  'Pic of foreign player wearing MI glove while batting go viral, PSL trolled',
#  'Please bowl slow to me next time: Afridi to Rauf after getting out for first-ball duck',
#  'Kohli always push the boundaries: Ex-Australia coach Lehmann',
#  "Wasim Jaffer troll Australia's new T20 rule with 'Gangs of Wasseypur' meme",
#  "Jimmy Neesham question Big Bash League's 'X-factor Player' rule",
#  'Ex-Bangladesh U-19 cricketer Mohammad Sozib dy by suicide aged 21',
#  'Rauf apologises to Afridi with folded hand after dismissing him for 1st ball duck',
#  'Gabon football team forced to sleep on airport floor, pic surface',
#  'Not pace but playing Rashid Khan wa a big challenge: Padikkal',
#  'Rahul is one of the best white-ball player at the moment: Nasser',
#  'Tim Paine in self-isolation due to COVID-19 outbreak in Adelaide',
#  'Best series of my life: Tendulkar on 2001 India-Aus Test series',
#  'Australia to introduce pre-match anti-racism ritual with the India series',
#  "Maninder Singh, Chetan Sharma apply for national selectors' post",
#  "Djokovic end his sixth year a World No 1, equal Sampras' record",
#  'Former England and Liverpool goalkeeper Ray Clemence dy at 72',
#  'Special for us, witnessing history being made: Vettel to Hamilton',
#  'Good thing that Virat ha a big say in Indian cricket: Greg Chappell',
#  'Ishant working with Mhambrey to become fit for Tests v Aus: Reports',
#  'Hamilton ‘bursts into tears’ after record-equalling 7th F1 title',
#  'SpaceX launch 4 astronaut on it first commercial crew flight for NASA',
#  "Who are the 4 astronaut on SpaceX's 1st commercial crew flight for NASA?",
#  'Zoom meeting could be behind surge in demand for plastic surgery: Experts',
#  "Don't want to regulate, it's their responsibility: Govt on OTT platform",
#  "4L malware, 375 cyberattacks seen daily: India's cybersecurity chief",
#  'Google tool let user know how long their Photos storage will last',
#  'Virgin Galactic delay test flight due to lockdown in New Mexico',
#  'Microsoft advises user against using SMS for two-factor authentication',
#  'Amazon apologises for saying Northern Ireland is not part of UK',
#  "US say sharing other firms' data with Google in lawsuit to weaken trust",
#  'Video game can be good for mental health: Oxford study',
#  "Software issue halt trading on Australia's stock exchange",
#  "17-yr-old Bangladeshi win Children's Peace Prize for fighting cybercrime",
#  "Apple tell Mac user it anti-malware feature doesn't spy on them",
#  'Man loses ₹5.85L to cyber fraudsters claiming to update UPI account',
#  'Zoom to temporarily lift 40-minute call limit globally',
#  "Privacy activist group file complaint against Apple's tracking tool",
#  'Zoom Founder Eric Yuan invests in Bengaluru startup Arzooo',
#  'Finance ministry give DGCA approval to set up Drones Directorate',
#  'Tesla open it largest EV super-charging station in US',
#  'Facial recognition system to identify bear created',
#  'Tech firm could be banned if they breach rules: EU',
#  "SpaceX's Starlink user report internet speed upto 200 Mbps",
#  'US President-elect Joe Biden congratulates SpaceX, NASA on launch',
#  "'Resident Evil' game maker say data of over 3.5L customer stolen",
#  'Dwayne Johnson fails to get into Porsche for chase sequence in movie, share pic',
#  "Govinda didn't visit when one of my twin wa fighting for life: Nephew Krushna",
#  "I don't want my son to be a singer, at least not in India: Sonu Nigam",
#  "Big B share fan-made collage showing Aaradhya's pic over 9 yr on her b'day",
#  "Big B's father's statue in Poland honoured with diya on Diwali, actor share pic",
#  "Salman is everything to me: Amaal on trolling by his fan for saying he's SRK fan",
#  'Tamil TV series actor hacked to death, CCTV footage show argument with gang',
#  "Zazie Beetz join Brad Pitt in action film 'Bullet Train': Reports",
#  "Do something original: 'Home Alone' director on Disney remake",
#  "He wa a gentle soul with abundant talent: Big B on Soumitra's demise",
#  "Justin Bieber, Jennifer Lopez win at People's Choice Awards 2020",
#  "He wa one of my oldest friends: Sharmila on Soumitra's demise",
#  "Please don't visit to pay condolences: Soumitra's daughter amid COVID-19",
#  "Feel like you've gone for a long shoot: Irrfan's son on late actor",
#  'Aditya made me feel comfortable on the set of Ludo: Sanya Malhotra',
#  'My role in Laxmii wa a cameo but it had a lot of emotions: Sharad',
#  'We decided to have the baby in Canada: Karanvir Bohra on third child',
#  "Matrix 4 break Germany's COVID-19 law by hosting party: Reports",
#  'Women are not offered cliched role like before: Samantha Akkineni',
#  "Aditya to start shooting for upcoming action film 'Om' in December",
#  "Chadwick won't be digitally recreated for Black Panther sequel: Marvel",
#  "You have to follow the studio: Jude Law on Depp's Fantastic Beasts exit",
#  "Lost a family member: Satyajit Ray's son on Soumitra Chatterjee's demise",
#  'Embassy of India in France pay tribute to Soumitra Chatterjee']

# %% [markdown]
# 5. Define a function named remove_stopwords. It should accept some text and return the text after removing all the stopwords.
#
#      This function should define two optional parameters, extra_words and exclude_words. These parameters should define any additional stop words to include, and any words that we don't want to remove.

# %%
def remove_stopwords(string, extra_words = [], exclude_words= []):
    stopword_list = stopwords.words('english')
    for word in extra_words:
        stopword_list.append(word)
    for word in exclude_words:
        stopword_list.remove(word)
    words = string.split()
    filtered_words = [w for w in words if w not in stopword_list]
    string_without_stopwords = ' '.join(filtered_words)
    return string_without_stopwords

# %%
# checking if the function created above works
title = list(df.title.astype(str))
new_title= []
for item in title:
    new_title.append(remove_stopwords(item))

new_title
# Out:
# ["Moderna's early data shows COVID-19 vaccine 94.5% effective",
#  "15 countries sign world's biggest free-trade pact India left last year",
#  "How Moderna's COVID-19 vaccine candidate compare Pfizer's?",
#  'Reliance Retail buys 96% stake Urban Ladder ₹182 crore',
#  'Reduce foreign funding 26% Oct 15, 2021: Govt digital media',
#  "India's longest gas blaze burning Assam oil well doused 5 months",
#  'Traders record ₹72,000 cr Diwali sales, hand China loss ₹40,000 cr: CAIT',
#  'Mahindra says still wears 1975 Kada blessed Golden Temple; shares pic',
#  "EU buy 405 mn doses CureVac's potential COVID-19 vaccine",
#  "Bharat Biotech's COVID-19 vaccine 'COVAXIN' enters phase-3 trials",
#  "Telcos, IT firms object TRAI's proposed cloud services regulation body",
#  "Software issue halts trading Australia's stock exchange",
#  "'Absolutely not' talks sell stake Mitsubishi: Nissan COO",
#  'Nissan considering 34% stake sale Mitsubishi: Reports',
#  'Ola, Swiggy put 5% wages social security fund draft rules: Report',
#  'UK ban sale new diesel, petrol cars 2030: Report',
#  'Wholesale price inflation rises 1.48% Oct, reaches 8-month high',
#  'Japan exits COVID-19-induced recession 5% growth Q3',
#  'Walmart nearly exits Japan selling $1 bn-stake retail chain Seiyu',
#  'Indian economy may recovering faster expected: Oxford Economics',
#  'Patanjali-owned Ruchi Soya launch FPO next year',
#  "India's diesel sales fall 5% y-o-y first half November",
#  'HDFC Mutual Fund appoints Navneet Munot MD CEO',
#  'Immigration officials stop businessman BR Shetty flying UAE',
#  'Tata Steel Q2 profit drops 63% due overseas losses',
#  'Olympic medalist working delivery boy generate income amid COVID-19',
#  "That best comment I saw whole day: Akash Ambani Vaughan's tweet MI",
#  "RCB issues clarification Kohli called 'hypocrite' Diwali message",
#  'McCullum trolls Lee apology 2011 bouncer broke nose',
#  "What new changes made T20 format Australia's Big Bash League?",
#  'Pic foreign player wearing MI gloves batting goes viral, PSL trolled',
#  'Please bowl slow next time: Afridi Rauf getting first-ball duck',
#  'Kohli always pushes boundaries: Ex-Australia coach Lehmann',
#  "Wasim Jaffer trolls Australia's new T20 rules 'Gangs Wasseypur' meme",
#  "Jimmy Neesham questions Big Bash League's 'X-factor Player' rule",
#  'Ex-Bangladesh U-19 cricketer Mohammad Sozib dies suicide aged 21',
#  'Rauf apologises Afridi folded hands dismissing 1st ball duck',
#  'Gabon football team forced sleep airport floor, pics surface',
#  'Not pace playing Rashid Khan big challenge: Padikkal',
#  'Rahul one best white-ball players moment: Nasser',
#  'Tim Paine self-isolation due COVID-19 outbreak Adelaide',
#  'Best series life: Tendulkar 2001 India-Aus Test series',
#  'Australia introduce pre-match anti-racism ritual India series',
#  "Maninder Singh, Chetan Sharma apply national selectors' post",
#  "Djokovic ends sixth year World No 1, equals Sampras' record",
#  'Former England Liverpool goalkeeper Ray Clemence dies 72',
#  'Special us, witnessing history made: Vettel Hamilton',
#  'Good thing Virat big say Indian cricket: Greg Chappell',
#  'Ishant working Mhambrey become fit Tests vs Aus: Reports',
#  'Hamilton ‘bursts tears’ record-equalling 7th F1 title',
#  'SpaceX launches 4 astronauts first commercial crew flight NASA',
#  "Who 4 astronauts SpaceX's 1st commercial crew flight NASA?",
#  'Zoom meetings could behind surge demand plastic surgery: Experts',
#  "Don't want regulate, responsibility: Govt OTT platforms",
#  "4L malware, 375 cyberattacks seen daily: India's cybersecurity chief",
#  'Google tool lets users know long Photos storage last',
#  'Virgin Galactic delays test flight due lockdown New Mexico',
#  'Microsoft advises users using SMS two-factor authentication',
#  'Amazon apologises saying Northern Ireland part UK',
#  "US says sharing firms' data Google lawsuit weaken trust",
#  'Video games good mental health: Oxford study',
#  "Software issue halts trading Australia's stock exchange",
#  "17-yr-old Bangladeshi wins Children's Peace Prize fighting cybercrime",
#  'Apple tells Mac users anti-malware feature spy',
#  'Man loses ₹5.85L cyber fraudsters claiming update UPI account',
#  'Zoom temporarily lift 40-minute call limit globally',
#  "Privacy activist group files complaints Apple's tracking tool",
#  'Zoom Founder Eric Yuan invests Bengaluru startup Arzooo',
#  'Finance ministry gives DGCA approval set Drones Directorate',
#  'Tesla opens largest EV super-charging station US',
#  'Facial recognition system identify bears created',
#  'Tech firms could banned breach rules: EU',
#  "SpaceX's Starlink users report internet speeds upto 200 Mbps",
#  'US President-elect Joe Biden congratulates SpaceX, NASA launch',
#  "'Resident Evil' game maker says data 3.5L customers stolen",
#  'Dwayne Johnson fails get Porsche chase sequence movie, shares pic',
#  'Govinda visit one twins fighting life: Nephew Krushna',
#  'I want son singer, least India: Sonu Nigam',
#  "Big B shares fan-made collage showing Aaradhya's pics 9 yrs b'day",
#  "Big B's father's statue Poland honoured diya Diwali, actor shares pic",
#  "Salman everything me: Amaal trolling fans saying he's SRK fan",
#  'Tamil TV series actor hacked death, CCTV footage shows argument gang',
#  "Zazie Beetz joins Brad Pitt action film 'Bullet Train': Reports",
#  "Do something original: 'Home Alone' director Disney remakes",
#  "He gentle soul abundant talent: Big B Soumitra's demise",
#  "Justin Bieber, Jennifer Lopez win People's Choice Awards 2020",
#  "He one oldest friends: Sharmila Soumitra's demise",
#  "Please visit pay condolences: Soumitra's daughter amid COVID-19",
#  "Feel like gone long shoot: Irrfan's son late actor",
#  'Aditya made feel comfortable sets Ludo: Sanya Malhotra',
#  'My role Laxmii cameo lot emotions: Sharad',
#  'We decided baby Canada: Karanvir Bohra third child',
#  "Matrix 4 breaks Germany's COVID-19 laws hosting party: Reports",
#  'Women offered cliched roles like before: Samantha Akkineni',
#  "Aditya start shooting upcoming action film 'Om' December",
#  'Chadwick digitally recreated Black Panther sequel: Marvel',
#  "You follow studio: Jude Law Depp's Fantastic Beasts exit",
#  "Lost family member: Satyajit Ray's son Soumitra Chatterjee's demise",
#  'Embassy India France pays tribute Soumitra Chatterjee']

# %% [markdown]
# 6. Use your data from the acquire to produce a dataframe of the news articles. Name the dataframe news_df.

# %%
news_df = acquire.get_news_articles()

# %% [markdown]
# 7. Make another dataframe for the Codeup blog posts. Name the dataframe codeup_df

# %%
codeup_df = acquire.get_blog_articles()

# %% [markdown]
# 8. For each dataframe, produce the following columns:
#
#     title to hold the title
#
#     original to hold the original article/post content
#
#     clean to hold the normalized and tokenized original with the stopwords removed.
#
#     stemmed to hold the stemmed version of the cleaned data.
#
#     lemmatized to hold the lemmatized version of the cleaned data.

# %%
news_df.rename(columns = {'content': 'original'}, inplace = True)

# %%
news_df['clean'] = news_df.apply(news_df.apply())
# Out:
#             topic                                              title  \
# 0        business  Moderna's early data shows its COVID-19 vaccin...
# 1        business  15 countries sign world's biggest free-trade p...
# 2        business  How does Moderna's COVID-19 vaccine candidate ...
# 3        business  Reduce foreign funding to 26% by Oct 15, 2021:...
# 4        business  Reliance Retail buys 96% stake in Urban Ladder...
# ..            ...                                                ...
# 94  entertainment  Women are not offered cliched roles like befor...
# 95  entertainment  My role in Laxmii was a cameo but it had a lot...
# 96  entertainment  Chadwick won't be digitally recreated for Blac...
# 97  entertainment  Aditya made me feel comfortable on the sets of...
# 98  entertainment  Matrix 4 breaks Germany's COVID-19 laws by hos...
#
#                author                                           original
# 0      Pragya Swastik  American biotechnology company Moderna on Mond...
# 1      Pragya Swastik  Fifteen Asia-Pacific countries signed the Regi...
# 2      Pragya Swastik  Moderna's initial results of late-stage trial ...
# 3      Pragya Swastik  The I&B Ministry on Monday asked digital media...
# 4   Rishabh Bhatnagar  Reliance Industries' retail arm Reliance Retai...
# ..                ...                                                ...
# 94       Kriti Sharma  Actress Samantha Akkineni, who will star in th...
# 95       Kriti Sharma  Speaking about his cameo in Akshay Kumar-starr...
# 96       Kriti Sharma  When asked if Marvel will digitally recreate l...
# 97       Kriti Sharma  Speaking about her experience of working with ...
# 98       Kriti Sharma  The team of Keanu Reeves' upcoming film 'The M...
#
# [99 rows x 4 columns]
